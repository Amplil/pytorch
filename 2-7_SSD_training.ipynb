# %% [markdown]
# # 2.7 学習と検証の実施
#
# - 本ファイルでは、SSDの学習と検証の実施を行います。手元のマシンで動作を確認後、AWSのGPUマシンで計算します。
# - p2.xlargeで約6時間かかります。

# %% [markdown]
# # 学習目標
#
# 1.	SSDの学習を実装できるようになる

# %% [markdown]
# # 事前準備
#
# - AWS EC2 のGPUインスタンスを使用します
# - フォルダ「utils」のssd_model.pyをします

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd "/content/drive/My Drive/Colab Notebooks/pytorch_advanced/2_objectdetection"
# Out:
# /content/drive/My Drive/Colab Notebooks/pytorch_advanced/2_objectdetection

# %%
# パッケージのimport
import os.path as osp
import random
import time

import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.utils.data as data

# %%
# 乱数のシードを設定
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("使用デバイス：", device)
# Out:
# 使用デバイス： cuda:0

# %% [markdown]
# # DatasetとDataLoaderを作成する

# %%
from utils.ssd_model import make_datapath_list, VOCDataset, DataTransform, Anno_xml2list, od_collate_fn


# ファイルパスのリストを取得
rootpath = "./data/VOCdevkit/VOC2012/"
train_img_list, train_anno_list, val_img_list, val_anno_list = make_datapath_list(
    rootpath)

# Datasetを作成
voc_classes = ['aeroplane', 'bicycle', 'bird', 'boat',
               'bottle', 'bus', 'car', 'cat', 'chair',
               'cow', 'diningtable', 'dog', 'horse',
               'motorbike', 'person', 'pottedplant',
               'sheep', 'sofa', 'train', 'tvmonitor']
color_mean = (104, 117, 123)  # (BGR)の色の平均値
input_size = 300  # 画像のinputサイズを300×300にする

train_dataset = VOCDataset(train_img_list, train_anno_list, phase="train", transform=DataTransform(
    input_size, color_mean), transform_anno=Anno_xml2list(voc_classes))

val_dataset = VOCDataset(val_img_list, val_anno_list, phase="val", transform=DataTransform(
    input_size, color_mean), transform_anno=Anno_xml2list(voc_classes))


# DataLoaderを作成する
batch_size = 32

train_dataloader = data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True, collate_fn=od_collate_fn)

val_dataloader = data.DataLoader(
    val_dataset, batch_size=batch_size, shuffle=False, collate_fn=od_collate_fn)

# 辞書オブジェクトにまとめる
dataloaders_dict = {"train": train_dataloader, "val": val_dataloader}

# %% [markdown]
# # ネットワークモデルの作成する

# %%
from utils.ssd_model import SSD

# SSD300の設定
ssd_cfg = {
    'num_classes': 21,  # 背景クラスを含めた合計クラス数
    'input_size': 300,  # 画像の入力サイズ
    'bbox_aspect_num': [4, 6, 6, 6, 4, 4],  # 出力するDBoxのアスペクト比の種類
    'feature_maps': [38, 19, 10, 5, 3, 1],  # 各sourceの画像サイズ
    'steps': [8, 16, 32, 64, 100, 300],  # DBOXの大きさを決める
    'min_sizes': [30, 60, 111, 162, 213, 264],  # DBOXの大きさを決める
    'max_sizes': [60, 111, 162, 213, 264, 315],  # DBOXの大きさを決める
    'aspect_ratios': [[2], [2, 3], [2, 3], [2, 3], [2], [2]],
}

# SSDネットワークモデル
net = SSD(phase="train", cfg=ssd_cfg)

# SSDの初期の重みを設定
# ssdのvgg部分に重みをロードする
vgg_weights = torch.load('./weights/vgg16_reducedfc.pth')
net.vgg.load_state_dict(vgg_weights)

# ssdのその他のネットワークの重みはHeの初期値で初期化


def weights_init(m):
    if isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight.data)
        if m.bias is not None:  # バイアス項がある場合
            nn.init.constant_(m.bias, 0.0)


# Heの初期値を適用
net.extras.apply(weights_init)
net.loc.apply(weights_init)
net.conf.apply(weights_init)

# GPUが使えるかを確認
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("使用デバイス：", device)

print('ネットワーク設定完了：学習済みの重みをロードしました')
# Out:
# 使用デバイス： cuda:0
# ネットワーク設定完了：学習済みの重みをロードしました

# %% [markdown]
# # 損失関数と最適化手法を定義する

# %%
from utils.ssd_model import MultiBoxLoss

# 損失関数の設定
criterion = MultiBoxLoss(jaccard_thresh=0.5, neg_pos=3, device=device)

# 最適化手法の設定
optimizer = optim.SGD(net.parameters(), lr=1e-3,
                      momentum=0.9, weight_decay=5e-4)

# %% [markdown]
# # 学習・検証を実施する

# %%
# モデルを学習させる関数を作成


def train_model(net, dataloaders_dict, criterion, optimizer, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # ネットワークをGPUへ
    net.to(device)

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # イテレーションカウンタをセット
    iteration = 1
    epoch_train_loss = 0.0  # epochの損失和
    epoch_val_loss = 0.0  # epochの損失和
    logs = []

    # epochのループ
    for epoch in range(num_epochs+1):

        # 開始時刻を保存
        t_epoch_start = time.time()
        t_iter_start = time.time()

        print('-------------')
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-------------')

        # epochごとの訓練と検証のループ
        for phase in ['train', 'val']:
            if phase == 'train':
                net.train()  # モデルを訓練モードに
                print('（train）')
            else:
                if((epoch+1) % 10 == 0):
                    net.eval()   # モデルを検証モードに
                    print('-------------')
                    print('（val）')
                else:
                    # 検証は10回に1回だけ行う
                    continue

            # データローダーからminibatchずつ取り出すループ
            for images, targets in dataloaders_dict[phase]:

                # GPUが使えるならGPUにデータを送る
                images = images.to(device)
                targets = [ann.to(device)
                           for ann in targets]  # リストの各要素のテンソルをGPUへ

                # optimizerを初期化
                optimizer.zero_grad()

                # 順伝搬（forward）計算
                with torch.set_grad_enabled(phase == 'train'):
                    # 順伝搬（forward）計算
                    outputs = net(images)

                    # 損失の計算
                    loss_l, loss_c = criterion(outputs, targets)
                    loss = loss_l + loss_c

                    # 訓練時はバックプロパゲーション
                    if phase == 'train':
                        loss.backward()  # 勾配の計算

                        # 勾配が大きくなりすぎると計算が不安定になるので、clipで最大でも勾配2.0に留める
                        nn.utils.clip_grad_value_(
                            net.parameters(), clip_value=2.0)

                        optimizer.step()  # パラメータ更新

                        if (iteration % 10 == 0):  # 10iterに1度、lossを表示
                            t_iter_finish = time.time()
                            duration = t_iter_finish - t_iter_start
                            print('イテレーション {} || Loss: {:.4f} || 10iter: {:.4f} sec.'.format(
                                iteration, loss.item(), duration))
                            t_iter_start = time.time()

                        epoch_train_loss += loss.item()
                        iteration += 1

                    # 検証時
                    else:
                        epoch_val_loss += loss.item()

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_TRAIN_Loss:{:.4f} ||Epoch_VAL_Loss:{:.4f}'.format(
            epoch+1, epoch_train_loss, epoch_val_loss))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

        # ログを保存
        log_epoch = {'epoch': epoch+1,
                     'train_loss': epoch_train_loss, 'val_loss': epoch_val_loss}
        logs.append(log_epoch)
        df = pd.DataFrame(logs)
        df.to_csv("log_output.csv")

        epoch_train_loss = 0.0  # epochの損失和
        epoch_val_loss = 0.0  # epochの損失和

        # ネットワークを保存する
        if ((epoch+1) % 10 == 0):
            torch.save(net.state_dict(), 'weights/ssd300_' +
                       str(epoch+1) + '.pth')

# %%
# 学習・検証を実行する
num_epochs= 50  
train_model(net, dataloaders_dict, criterion, optimizer, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 1/50
# -------------
# （train）
# /content/drive/My Drive/Colab Notebooks/pytorch_advanced/2_objectdetection/utils/data_augumentation.py:246: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   mode = random.choice(self.sample_options)
# イテレーション 10 || Loss: 17.1477 || 10iter: 345.8130 sec.
# イテレーション 20 || Loss: 14.2005 || 10iter: 167.1201 sec.
# イテレーション 30 || Loss: 13.5163 || 10iter: 164.8585 sec.
# イテレーション 40 || Loss: 10.5735 || 10iter: 166.6316 sec.
# イテレーション 50 || Loss: 10.0908 || 10iter: 167.0028 sec.
# イテレーション 60 || Loss: 9.1370 || 10iter: 163.9599 sec.
# イテレーション 70 || Loss: 9.2129 || 10iter: 164.2891 sec.
# イテレーション 80 || Loss: 9.0470 || 10iter: 166.1527 sec.
# イテレーション 90 || Loss: 8.5663 || 10iter: 166.8327 sec.
# イテレーション 100 || Loss: 10.8504 || 10iter: 166.4848 sec.
# イテレーション 110 || Loss: 8.5514 || 10iter: 169.2666 sec.
# イテレーション 120 || Loss: 7.9499 || 10iter: 166.3821 sec.
# イテレーション 130 || Loss: 8.5688 || 10iter: 172.7421 sec.
# イテレーション 140 || Loss: 8.2893 || 10iter: 171.3070 sec.
# イテレーション 150 || Loss: 7.6845 || 10iter: 169.6469 sec.
# イテレーション 160 || Loss: 8.4295 || 10iter: 169.3900 sec.
# イテレーション 170 || Loss: 7.7105 || 10iter: 168.7449 sec.
# -------------
# epoch 1 || Epoch_TRAIN_Loss:1820.1771 ||Epoch_VAL_Loss:0.0000
# timer:  3189.2895 sec.
# -------------
# Epoch 2/50
# -------------
# （train）
# イテレーション 180 || Loss: 7.5897 || 10iter: 0.9317 sec.
# イテレーション 190 || Loss: 7.9900 || 10iter: 16.2914 sec.
# イテレーション 200 || Loss: 7.7484 || 10iter: 15.7449 sec.
# イテレーション 210 || Loss: 7.7281 || 10iter: 15.8467 sec.
# イテレーション 220 || Loss: 9.8779 || 10iter: 15.5332 sec.
# イテレーション 230 || Loss: 8.9927 || 10iter: 15.6637 sec.
# イテレーション 240 || Loss: 7.6416 || 10iter: 15.7961 sec.
# イテレーション 250 || Loss: 8.0904 || 10iter: 15.7438 sec.
# イテレーション 260 || Loss: 7.4405 || 10iter: 15.7302 sec.
# イテレーション 270 || Loss: 7.7266 || 10iter: 15.3844 sec.
# イテレーション 280 || Loss: 7.8150 || 10iter: 15.8720 sec.
# イテレーション 290 || Loss: 7.8969 || 10iter: 16.0476 sec.
# イテレーション 300 || Loss: 6.8446 || 10iter: 15.9159 sec.
# イテレーション 310 || Loss: 7.8407 || 10iter: 16.0227 sec.
# イテレーション 320 || Loss: 7.0408 || 10iter: 15.9124 sec.
# イテレーション 330 || Loss: 6.9215 || 10iter: 15.9863 sec.
# イテレーション 340 || Loss: 7.4314 || 10iter: 16.0013 sec.
# イテレーション 350 || Loss: 7.1175 || 10iter: 16.1369 sec.
# -------------
# epoch 2 || Epoch_TRAIN_Loss:1376.8665 ||Epoch_VAL_Loss:0.0000
# timer:  294.9793 sec.
# -------------
# Epoch 3/50
# -------------
# （train）
# イテレーション 360 || Loss: 7.3778 || 10iter: 2.6726 sec.
# イテレーション 370 || Loss: 7.1903 || 10iter: 15.9447 sec.
# イテレーション 380 || Loss: 7.1058 || 10iter: 15.7435 sec.
# イテレーション 390 || Loss: 6.8482 || 10iter: 15.9867 sec.
# イテレーション 400 || Loss: 6.9245 || 10iter: 15.9691 sec.
# イテレーション 410 || Loss: 7.4121 || 10iter: 15.8500 sec.
# イテレーション 420 || Loss: 7.7459 || 10iter: 15.8780 sec.
# イテレーション 430 || Loss: 6.7949 || 10iter: 16.0147 sec.
# イテレーション 440 || Loss: 6.7107 || 10iter: 15.7596 sec.
# イテレーション 450 || Loss: 7.4879 || 10iter: 16.0139 sec.
# イテレーション 460 || Loss: 7.5021 || 10iter: 15.6994 sec.
# イテレーション 470 || Loss: 7.0101 || 10iter: 16.2652 sec.
# イテレーション 480 || Loss: 7.1792 || 10iter: 16.0387 sec.
# イテレーション 490 || Loss: 6.9561 || 10iter: 15.7646 sec.
# イテレーション 500 || Loss: 6.9834 || 10iter: 15.9993 sec.
# イテレーション 510 || Loss: 6.5806 || 10iter: 15.6109 sec.
# イテレーション 520 || Loss: 6.8688 || 10iter: 15.9940 sec.
# イテレーション 530 || Loss: 6.9651 || 10iter: 15.7110 sec.
# -------------
# epoch 3 || Epoch_TRAIN_Loss:1261.2261 ||Epoch_VAL_Loss:0.0000
# timer:  295.8263 sec.
# -------------
# Epoch 4/50
# -------------
# （train）
# イテレーション 540 || Loss: 6.6202 || 10iter: 4.4775 sec.
# イテレーション 550 || Loss: 7.0660 || 10iter: 15.6470 sec.
# イテレーション 560 || Loss: 7.2268 || 10iter: 15.9246 sec.
# イテレーション 570 || Loss: 6.5243 || 10iter: 16.0249 sec.
# イテレーション 580 || Loss: 6.7628 || 10iter: 15.8608 sec.
# イテレーション 590 || Loss: 6.6303 || 10iter: 15.6267 sec.
# イテレーション 600 || Loss: 6.7660 || 10iter: 15.5867 sec.
# イテレーション 610 || Loss: 6.5790 || 10iter: 15.7409 sec.
# イテレーション 620 || Loss: 6.3729 || 10iter: 15.8717 sec.
# イテレーション 630 || Loss: 6.5026 || 10iter: 16.0289 sec.
# イテレーション 640 || Loss: 6.1182 || 10iter: 15.8954 sec.
# イテレーション 650 || Loss: 6.1073 || 10iter: 15.9791 sec.
# イテレーション 660 || Loss: 6.3457 || 10iter: 15.8210 sec.
# イテレーション 670 || Loss: 6.7774 || 10iter: 15.9548 sec.
# イテレーション 680 || Loss: 6.4035 || 10iter: 15.9113 sec.
# イテレーション 690 || Loss: 6.2963 || 10iter: 15.7507 sec.
# イテレーション 700 || Loss: 6.5659 || 10iter: 16.0555 sec.
# イテレーション 710 || Loss: 6.4657 || 10iter: 15.7935 sec.
# -------------
# epoch 4 || Epoch_TRAIN_Loss:1179.1573 ||Epoch_VAL_Loss:0.0000
# timer:  294.7670 sec.
# -------------
# Epoch 5/50
# -------------
# （train）
# イテレーション 720 || Loss: 6.2487 || 10iter: 5.9095 sec.
# イテレーション 730 || Loss: 6.5789 || 10iter: 15.8971 sec.
# イテレーション 740 || Loss: 6.4671 || 10iter: 16.0341 sec.
# イテレーション 750 || Loss: 6.3263 || 10iter: 15.8851 sec.
# イテレーション 760 || Loss: 6.5931 || 10iter: 15.9771 sec.
# イテレーション 770 || Loss: 6.6096 || 10iter: 15.6731 sec.
# イテレーション 780 || Loss: 6.4127 || 10iter: 15.7650 sec.
# イテレーション 790 || Loss: 6.1719 || 10iter: 15.6508 sec.
# イテレーション 800 || Loss: 6.5489 || 10iter: 15.4786 sec.
# イテレーション 810 || Loss: 6.4996 || 10iter: 15.8481 sec.
# イテレーション 820 || Loss: 6.3334 || 10iter: 15.8273 sec.
# イテレーション 830 || Loss: 5.6445 || 10iter: 15.7946 sec.
# イテレーション 840 || Loss: 6.6467 || 10iter: 15.7735 sec.
# イテレーション 850 || Loss: 6.2906 || 10iter: 15.8892 sec.
# イテレーション 860 || Loss: 6.1189 || 10iter: 15.7396 sec.
# イテレーション 870 || Loss: 6.1191 || 10iter: 15.6836 sec.
# イテレーション 880 || Loss: 6.0148 || 10iter: 16.0313 sec.
# イテレーション 890 || Loss: 6.3281 || 10iter: 15.5892 sec.
# -------------
# epoch 5 || Epoch_TRAIN_Loss:1125.2168 ||Epoch_VAL_Loss:0.0000
# timer:  293.5839 sec.
# -------------
# Epoch 6/50
# -------------
# （train）
# イテレーション 900 || Loss: 5.8354 || 10iter: 7.6978 sec.
# イテレーション 910 || Loss: 6.4377 || 10iter: 15.7530 sec.
# イテレーション 920 || Loss: 6.1899 || 10iter: 15.8296 sec.
# イテレーション 930 || Loss: 6.6262 || 10iter: 15.9736 sec.
# イテレーション 940 || Loss: 6.2521 || 10iter: 15.9971 sec.
# イテレーション 950 || Loss: 6.0385 || 10iter: 15.6346 sec.
# イテレーション 960 || Loss: 6.6148 || 10iter: 15.7081 sec.
# イテレーション 970 || Loss: 6.6429 || 10iter: 15.6922 sec.
# イテレーション 980 || Loss: 6.2707 || 10iter: 15.7783 sec.
# イテレーション 990 || Loss: 6.1957 || 10iter: 15.7217 sec.
# イテレーション 1000 || Loss: 5.8878 || 10iter: 15.5763 sec.
# イテレーション 1010 || Loss: 6.0520 || 10iter: 15.6550 sec.
# イテレーション 1020 || Loss: 6.1400 || 10iter: 15.7408 sec.
# イテレーション 1030 || Loss: 5.9982 || 10iter: 15.8639 sec.
# イテレーション 1040 || Loss: 5.8126 || 10iter: 16.1445 sec.
# イテレーション 1050 || Loss: 6.6006 || 10iter: 16.1526 sec.
# イテレーション 1060 || Loss: 6.2955 || 10iter: 15.8789 sec.
# イテレーション 1070 || Loss: 5.9213 || 10iter: 15.9759 sec.
# -------------
# epoch 6 || Epoch_TRAIN_Loss:1091.9242 ||Epoch_VAL_Loss:0.0000
# timer:  294.7127 sec.
# -------------
# Epoch 7/50
# -------------
# （train）
# イテレーション 1080 || Loss: 6.4733 || 10iter: 9.3487 sec.
# イテレーション 1090 || Loss: 6.0428 || 10iter: 15.5551 sec.
# イテレーション 1100 || Loss: 6.4309 || 10iter: 15.9677 sec.
# イテレーション 1110 || Loss: 5.6813 || 10iter: 15.8250 sec.
# イテレーション 1120 || Loss: 5.8363 || 10iter: 15.7676 sec.
# イテレーション 1130 || Loss: 5.6122 || 10iter: 15.8597 sec.
# イテレーション 1140 || Loss: 5.6976 || 10iter: 15.8761 sec.
# イテレーション 1150 || Loss: 6.1313 || 10iter: 15.6697 sec.
# イテレーション 1160 || Loss: 6.1745 || 10iter: 15.9170 sec.
# イテレーション 1170 || Loss: 5.8163 || 10iter: 15.7992 sec.
# イテレーション 1180 || Loss: 6.0942 || 10iter: 15.7698 sec.
# イテレーション 1190 || Loss: 6.0402 || 10iter: 15.7042 sec.
# イテレーション 1200 || Loss: 6.2386 || 10iter: 15.5273 sec.
# イテレーション 1210 || Loss: 5.5759 || 10iter: 15.7958 sec.
# イテレーション 1220 || Loss: 5.8374 || 10iter: 15.8502 sec.
# イテレーション 1230 || Loss: 5.2653 || 10iter: 15.8216 sec.
# イテレーション 1240 || Loss: 5.6441 || 10iter: 16.0106 sec.
# イテレーション 1250 || Loss: 5.9646 || 10iter: 16.1682 sec.
# -------------
# epoch 7 || Epoch_TRAIN_Loss:1043.3010 ||Epoch_VAL_Loss:0.0000
# timer:  294.2899 sec.
# -------------
# Epoch 8/50
# -------------
# （train）
# イテレーション 1260 || Loss: 5.8122 || 10iter: 10.6617 sec.
# イテレーション 1270 || Loss: 5.7713 || 10iter: 16.0917 sec.
# イテレーション 1280 || Loss: 6.1447 || 10iter: 15.6623 sec.
# イテレーション 1290 || Loss: 5.6227 || 10iter: 15.7179 sec.
# イテレーション 1300 || Loss: 5.5072 || 10iter: 15.4926 sec.
# イテレーション 1310 || Loss: 5.9203 || 10iter: 15.6633 sec.
# イテレーション 1320 || Loss: 5.7646 || 10iter: 16.1383 sec.
# イテレーション 1330 || Loss: 5.7828 || 10iter: 15.8236 sec.
# イテレーション 1340 || Loss: 5.7747 || 10iter: 15.8326 sec.
# イテレーション 1350 || Loss: 5.6774 || 10iter: 15.7384 sec.
# イテレーション 1360 || Loss: 5.5624 || 10iter: 16.0176 sec.
# イテレーション 1370 || Loss: 5.1382 || 10iter: 15.6302 sec.
# イテレーション 1380 || Loss: 5.4459 || 10iter: 15.6937 sec.
# イテレーション 1390 || Loss: 5.9324 || 10iter: 16.1069 sec.
# イテレーション 1400 || Loss: 5.2383 || 10iter: 15.6806 sec.
# イテレーション 1410 || Loss: 5.9545 || 10iter: 15.8906 sec.
# イテレーション 1420 || Loss: 5.6101 || 10iter: 15.6647 sec.
# イテレーション 1430 || Loss: 5.5086 || 10iter: 15.7329 sec.
# -------------
# epoch 8 || Epoch_TRAIN_Loss:1010.0380 ||Epoch_VAL_Loss:0.0000
# timer:  293.6885 sec.
# -------------
# Epoch 9/50
# -------------
# （train）
# イテレーション 1440 || Loss: 5.7312 || 10iter: 12.4314 sec.
# イテレーション 1450 || Loss: 5.7673 || 10iter: 16.2546 sec.
# イテレーション 1460 || Loss: 5.6261 || 10iter: 15.7539 sec.
# イテレーション 1470 || Loss: 5.7643 || 10iter: 15.4028 sec.
# イテレーション 1480 || Loss: 6.1282 || 10iter: 15.8441 sec.
# イテレーション 1490 || Loss: 5.4823 || 10iter: 15.3899 sec.
# イテレーション 1500 || Loss: 5.0908 || 10iter: 16.0403 sec.
# イテレーション 1510 || Loss: 5.6623 || 10iter: 15.8172 sec.
# イテレーション 1520 || Loss: 5.2360 || 10iter: 15.6037 sec.
# イテレーション 1530 || Loss: 4.9510 || 10iter: 15.8176 sec.
# イテレーション 1540 || Loss: 5.5199 || 10iter: 15.9027 sec.
# イテレーション 1550 || Loss: 5.8268 || 10iter: 16.1306 sec.
# イテレーション 1560 || Loss: 5.7211 || 10iter: 15.8706 sec.
# イテレーション 1570 || Loss: 5.1798 || 10iter: 15.6504 sec.
# イテレーション 1580 || Loss: 5.5672 || 10iter: 15.9438 sec.
# イテレーション 1590 || Loss: 5.5597 || 10iter: 15.6397 sec.
# イテレーション 1600 || Loss: 4.8714 || 10iter: 15.8387 sec.
# イテレーション 1610 || Loss: 5.1165 || 10iter: 15.8525 sec.
# -------------
# epoch 9 || Epoch_TRAIN_Loss:978.5680 ||Epoch_VAL_Loss:0.0000
# timer:  294.0784 sec.
# -------------
# Epoch 10/50
# -------------
# （train）
# イテレーション 1620 || Loss: 5.5571 || 10iter: 14.2024 sec.
# イテレーション 1630 || Loss: 5.2676 || 10iter: 15.5951 sec.
# イテレーション 1640 || Loss: 5.5397 || 10iter: 15.8204 sec.
# イテレーション 1650 || Loss: 5.4694 || 10iter: 15.7069 sec.
# イテレーション 1660 || Loss: 4.9983 || 10iter: 15.6420 sec.
# イテレーション 1670 || Loss: 4.9430 || 10iter: 15.8579 sec.
# イテレーション 1680 || Loss: 5.5174 || 10iter: 15.6187 sec.
# イテレーション 1690 || Loss: 5.5530 || 10iter: 15.6636 sec.
# イテレーション 1700 || Loss: 5.3802 || 10iter: 16.0564 sec.
# イテレーション 1710 || Loss: 5.1033 || 10iter: 15.7618 sec.
# イテレーション 1720 || Loss: 4.9228 || 10iter: 15.6603 sec.
# イテレーション 1730 || Loss: 5.3457 || 10iter: 15.7604 sec.
# イテレーション 1740 || Loss: 5.4719 || 10iter: 15.6166 sec.
# イテレーション 1750 || Loss: 5.5094 || 10iter: 15.8326 sec.
# イテレーション 1760 || Loss: 5.7903 || 10iter: 15.8316 sec.
# イテレーション 1770 || Loss: 5.5629 || 10iter: 15.6634 sec.
# イテレーション 1780 || Loss: 5.2607 || 10iter: 15.5958 sec.
# イテレーション 1790 || Loss: 4.9076 || 10iter: 15.5202 sec.
# -------------
# （val）
# -------------
# epoch 10 || Epoch_TRAIN_Loss:958.6693 ||Epoch_VAL_Loss:962.4804
# timer:  3238.3369 sec.
# -------------
# Epoch 11/50
# -------------
# （train）
# イテレーション 1800 || Loss: 4.8740 || 10iter: 16.2328 sec.
# イテレーション 1810 || Loss: 5.5457 || 10iter: 16.1148 sec.
# イテレーション 1820 || Loss: 4.9929 || 10iter: 15.7221 sec.
# イテレーション 1830 || Loss: 5.1550 || 10iter: 15.8936 sec.
# イテレーション 1840 || Loss: 4.8025 || 10iter: 15.5805 sec.
# イテレーション 1850 || Loss: 5.7424 || 10iter: 16.0438 sec.
# イテレーション 1860 || Loss: 6.3351 || 10iter: 15.9728 sec.
# イテレーション 1870 || Loss: 5.5128 || 10iter: 16.0178 sec.
# イテレーション 1880 || Loss: 5.1422 || 10iter: 15.9174 sec.
# イテレーション 1890 || Loss: 4.7702 || 10iter: 16.2568 sec.
# イテレーション 1900 || Loss: 5.0178 || 10iter: 15.9688 sec.
# イテレーション 1910 || Loss: 5.1949 || 10iter: 16.0707 sec.
# イテレーション 1920 || Loss: 5.6611 || 10iter: 15.8898 sec.
# イテレーション 1930 || Loss: 5.3365 || 10iter: 15.8638 sec.
# イテレーション 1940 || Loss: 5.4861 || 10iter: 15.7296 sec.
# イテレーション 1950 || Loss: 4.8217 || 10iter: 15.9971 sec.
# イテレーション 1960 || Loss: 4.8289 || 10iter: 15.9089 sec.
# -------------
# epoch 11 || Epoch_TRAIN_Loss:936.6502 ||Epoch_VAL_Loss:0.0000
# timer:  296.6870 sec.
# -------------
# Epoch 12/50
# -------------
# （train）
# イテレーション 1970 || Loss: 4.3712 || 10iter: 0.9113 sec.
# イテレーション 1980 || Loss: 4.8193 || 10iter: 15.7043 sec.
# イテレーション 1990 || Loss: 5.1362 || 10iter: 16.1519 sec.
# イテレーション 2000 || Loss: 5.3763 || 10iter: 15.7618 sec.
# イテレーション 2010 || Loss: 5.1208 || 10iter: 15.5845 sec.
# イテレーション 2020 || Loss: 5.8225 || 10iter: 15.8405 sec.
# イテレーション 2030 || Loss: 5.0852 || 10iter: 15.8342 sec.
# イテレーション 2040 || Loss: 5.2598 || 10iter: 15.9464 sec.
# イテレーション 2050 || Loss: 4.7277 || 10iter: 15.9271 sec.
# イテレーション 2060 || Loss: 5.1590 || 10iter: 15.9781 sec.
# イテレーション 2070 || Loss: 5.0134 || 10iter: 16.1660 sec.
# イテレーション 2080 || Loss: 5.1903 || 10iter: 15.9965 sec.
# イテレーション 2090 || Loss: 5.5634 || 10iter: 15.7548 sec.
# イテレーション 2100 || Loss: 4.8217 || 10iter: 15.8574 sec.
# イテレーション 2110 || Loss: 5.2124 || 10iter: 15.6576 sec.
# イテレーション 2120 || Loss: 5.1507 || 10iter: 15.9584 sec.
# イテレーション 2130 || Loss: 4.7708 || 10iter: 15.8482 sec.
# イテレーション 2140 || Loss: 5.0086 || 10iter: 15.6412 sec.
# -------------
# epoch 12 || Epoch_TRAIN_Loss:914.6547 ||Epoch_VAL_Loss:0.0000
# timer:  294.8528 sec.
# -------------
# Epoch 13/50
# -------------
# （train）
# イテレーション 2150 || Loss: 4.9545 || 10iter: 2.5195 sec.
# イテレーション 2160 || Loss: 5.3999 || 10iter: 15.9781 sec.
# イテレーション 2170 || Loss: 5.0129 || 10iter: 16.0882 sec.
# イテレーション 2180 || Loss: 4.6064 || 10iter: 15.9043 sec.
# イテレーション 2190 || Loss: 5.0005 || 10iter: 15.9826 sec.
# イテレーション 2200 || Loss: 4.6512 || 10iter: 15.6694 sec.
# イテレーション 2210 || Loss: 5.1545 || 10iter: 15.9622 sec.
# イテレーション 2220 || Loss: 4.6566 || 10iter: 15.7610 sec.
# イテレーション 2230 || Loss: 4.8809 || 10iter: 15.8218 sec.
# イテレーション 2240 || Loss: 5.3214 || 10iter: 15.8975 sec.
# イテレーション 2250 || Loss: 5.0816 || 10iter: 15.8345 sec.
# イテレーション 2260 || Loss: 4.8893 || 10iter: 15.8410 sec.
# イテレーション 2270 || Loss: 5.7013 || 10iter: 16.0695 sec.
# イテレーション 2280 || Loss: 5.6565 || 10iter: 16.0760 sec.
# イテレーション 2290 || Loss: 5.8572 || 10iter: 15.9155 sec.
# イテレーション 2300 || Loss: 5.2337 || 10iter: 15.7593 sec.
# イテレーション 2310 || Loss: 4.9400 || 10iter: 15.9039 sec.
# イテレーション 2320 || Loss: 4.7531 || 10iter: 15.8731 sec.
# -------------
# epoch 13 || Epoch_TRAIN_Loss:900.4168 ||Epoch_VAL_Loss:0.0000
# timer:  295.6855 sec.
# -------------
# Epoch 14/50
# -------------
# （train）
# イテレーション 2330 || Loss: 5.1658 || 10iter: 4.5376 sec.
# イテレーション 2340 || Loss: 5.4808 || 10iter: 15.9394 sec.
# イテレーション 2350 || Loss: 5.0912 || 10iter: 15.8549 sec.
# イテレーション 2360 || Loss: 5.0220 || 10iter: 15.8648 sec.
# イテレーション 2370 || Loss: 5.3461 || 10iter: 15.9433 sec.
# イテレーション 2380 || Loss: 4.8856 || 10iter: 15.9053 sec.
# イテレーション 2390 || Loss: 5.3028 || 10iter: 15.9184 sec.
# イテレーション 2400 || Loss: 5.0532 || 10iter: 15.8932 sec.
# イテレーション 2410 || Loss: 5.1796 || 10iter: 15.8062 sec.
# イテレーション 2420 || Loss: 4.9832 || 10iter: 15.9288 sec.
# イテレーション 2430 || Loss: 5.3182 || 10iter: 16.2061 sec.
# イテレーション 2440 || Loss: 5.2727 || 10iter: 15.8438 sec.
# イテレーション 2450 || Loss: 4.1989 || 10iter: 16.0314 sec.
# イテレーション 2460 || Loss: 5.2689 || 10iter: 15.9228 sec.
# イテレーション 2470 || Loss: 5.0706 || 10iter: 15.7743 sec.
# イテレーション 2480 || Loss: 4.9758 || 10iter: 15.9351 sec.
# イテレーション 2490 || Loss: 4.9801 || 10iter: 15.9810 sec.
# イテレーション 2500 || Loss: 5.7505 || 10iter: 16.0534 sec.
# -------------
# epoch 14 || Epoch_TRAIN_Loss:888.2451 ||Epoch_VAL_Loss:0.0000
# timer:  296.5729 sec.
# -------------
# Epoch 15/50
# -------------
# （train）
# イテレーション 2510 || Loss: 4.8010 || 10iter: 5.9530 sec.
# イテレーション 2520 || Loss: 4.7958 || 10iter: 15.6758 sec.
# イテレーション 2530 || Loss: 4.3831 || 10iter: 16.0477 sec.
# イテレーション 2540 || Loss: 4.7167 || 10iter: 15.7730 sec.
# イテレーション 2550 || Loss: 4.7987 || 10iter: 15.8207 sec.
# イテレーション 2560 || Loss: 4.4837 || 10iter: 15.8129 sec.
# イテレーション 2570 || Loss: 4.6055 || 10iter: 15.7582 sec.
# イテレーション 2580 || Loss: 4.4201 || 10iter: 15.8884 sec.
# イテレーション 2590 || Loss: 4.5645 || 10iter: 15.8959 sec.
# イテレーション 2600 || Loss: 4.5238 || 10iter: 15.7393 sec.
# イテレーション 2610 || Loss: 4.6940 || 10iter: 15.8866 sec.
# イテレーション 2620 || Loss: 4.6670 || 10iter: 15.7714 sec.
# イテレーション 2630 || Loss: 4.4500 || 10iter: 15.7135 sec.
# イテレーション 2640 || Loss: 4.7415 || 10iter: 15.8349 sec.
# イテレーション 2650 || Loss: 4.6040 || 10iter: 16.0044 sec.
# イテレーション 2660 || Loss: 5.1308 || 10iter: 15.5844 sec.
# イテレーション 2670 || Loss: 5.1897 || 10iter: 15.9501 sec.
# イテレーション 2680 || Loss: 4.7013 || 10iter: 15.6476 sec.
# -------------
# epoch 15 || Epoch_TRAIN_Loss:862.5912 ||Epoch_VAL_Loss:0.0000
# timer:  294.2164 sec.
# -------------
# Epoch 16/50
# -------------
# （train）
# イテレーション 2690 || Loss: 4.6564 || 10iter: 7.6502 sec.
# イテレーション 2700 || Loss: 4.6586 || 10iter: 15.9609 sec.
# イテレーション 2710 || Loss: 4.5665 || 10iter: 15.8767 sec.
# イテレーション 2720 || Loss: 4.8101 || 10iter: 15.9077 sec.
# イテレーション 2730 || Loss: 4.8945 || 10iter: 16.0149 sec.
# イテレーション 2740 || Loss: 5.2038 || 10iter: 15.9247 sec.
# イテレーション 2750 || Loss: 4.3821 || 10iter: 16.0741 sec.
# イテレーション 2760 || Loss: 5.2691 || 10iter: 15.8267 sec.
# イテレーション 2770 || Loss: 4.9143 || 10iter: 15.8977 sec.
# イテレーション 2780 || Loss: 5.1755 || 10iter: 15.8231 sec.
# イテレーション 2790 || Loss: 4.4368 || 10iter: 16.0132 sec.
# イテレーション 2800 || Loss: 5.2583 || 10iter: 15.7886 sec.
# イテレーション 2810 || Loss: 4.7050 || 10iter: 15.8780 sec.
# イテレーション 2820 || Loss: 4.7338 || 10iter: 16.1585 sec.
# イテレーション 2830 || Loss: 4.4253 || 10iter: 15.8511 sec.
# イテレーション 2840 || Loss: 4.8270 || 10iter: 16.0878 sec.
# イテレーション 2850 || Loss: 4.6490 || 10iter: 15.7784 sec.
# イテレーション 2860 || Loss: 5.3028 || 10iter: 16.0142 sec.
# -------------
# epoch 16 || Epoch_TRAIN_Loss:855.5734 ||Epoch_VAL_Loss:0.0000
# timer:  296.3944 sec.
# -------------
# Epoch 17/50
# -------------
# （train）
# イテレーション 2870 || Loss: 4.5082 || 10iter: 9.1691 sec.
# イテレーション 2880 || Loss: 4.5974 || 10iter: 15.6262 sec.
# イテレーション 2890 || Loss: 4.9303 || 10iter: 15.9708 sec.
# イテレーション 2900 || Loss: 4.4093 || 10iter: 15.8057 sec.
# イテレーション 2910 || Loss: 4.8032 || 10iter: 15.8721 sec.
# イテレーション 2920 || Loss: 5.2532 || 10iter: 15.7912 sec.
# イテレーション 2930 || Loss: 4.9917 || 10iter: 15.9125 sec.
# イテレーション 2940 || Loss: 4.7065 || 10iter: 16.1199 sec.
# イテレーション 2950 || Loss: 4.6304 || 10iter: 16.0385 sec.
# イテレーション 2960 || Loss: 5.2400 || 10iter: 15.9538 sec.
# イテレーション 2970 || Loss: 4.5071 || 10iter: 15.7223 sec.
# イテレーション 2980 || Loss: 4.9590 || 10iter: 15.9847 sec.
# イテレーション 2990 || Loss: 4.5713 || 10iter: 16.1807 sec.
# イテレーション 3000 || Loss: 5.0424 || 10iter: 15.9198 sec.
# イテレーション 3010 || Loss: 5.2468 || 10iter: 15.8490 sec.
# イテレーション 3020 || Loss: 4.5333 || 10iter: 15.9707 sec.
# イテレーション 3030 || Loss: 5.1573 || 10iter: 15.9471 sec.
# イテレーション 3040 || Loss: 4.8502 || 10iter: 15.6455 sec.
# -------------
# epoch 17 || Epoch_TRAIN_Loss:839.2470 ||Epoch_VAL_Loss:0.0000
# timer:  295.6735 sec.
# -------------
# Epoch 18/50
# -------------
# （train）
# イテレーション 3050 || Loss: 4.8334 || 10iter: 10.6885 sec.
# イテレーション 3060 || Loss: 4.6625 || 10iter: 16.0443 sec.
# イテレーション 3070 || Loss: 4.6257 || 10iter: 15.9017 sec.
# イテレーション 3080 || Loss: 4.1649 || 10iter: 15.7660 sec.
# イテレーション 3090 || Loss: 4.0988 || 10iter: 16.0452 sec.
# イテレーション 3100 || Loss: 4.6689 || 10iter: 16.1788 sec.
# イテレーション 3110 || Loss: 4.7383 || 10iter: 15.7975 sec.
# イテレーション 3120 || Loss: 4.5641 || 10iter: 15.7918 sec.
# イテレーション 3130 || Loss: 4.5906 || 10iter: 15.7525 sec.
# イテレーション 3140 || Loss: 4.5713 || 10iter: 16.3053 sec.
# イテレーション 3150 || Loss: 4.3561 || 10iter: 15.9303 sec.
# イテレーション 3160 || Loss: 4.8739 || 10iter: 16.1207 sec.
# イテレーション 3170 || Loss: 4.7467 || 10iter: 16.1823 sec.
# イテレーション 3180 || Loss: 5.2668 || 10iter: 16.0453 sec.
# イテレーション 3190 || Loss: 4.7267 || 10iter: 15.9720 sec.
# イテレーション 3200 || Loss: 4.3725 || 10iter: 15.9049 sec.
# イテレーション 3210 || Loss: 4.9576 || 10iter: 16.2140 sec.
# イテレーション 3220 || Loss: 5.0340 || 10iter: 16.2240 sec.
# -------------
# epoch 18 || Epoch_TRAIN_Loss:826.4269 ||Epoch_VAL_Loss:0.0000
# timer:  297.2785 sec.
# -------------
# Epoch 19/50
# -------------
# （train）
# イテレーション 3230 || Loss: 5.0539 || 10iter: 12.6852 sec.
# イテレーション 3240 || Loss: 4.6360 || 10iter: 16.0366 sec.
# イテレーション 3250 || Loss: 4.6600 || 10iter: 15.6927 sec.
# イテレーション 3260 || Loss: 4.5089 || 10iter: 15.8060 sec.
# イテレーション 3270 || Loss: 4.4389 || 10iter: 15.9885 sec.
# イテレーション 3280 || Loss: 4.0950 || 10iter: 15.9347 sec.
# イテレーション 3290 || Loss: 4.3406 || 10iter: 15.6294 sec.
# イテレーション 3300 || Loss: 4.3618 || 10iter: 15.8784 sec.
# イテレーション 3310 || Loss: 4.6422 || 10iter: 15.8880 sec.
# イテレーション 3320 || Loss: 4.2536 || 10iter: 16.0480 sec.
# イテレーション 3330 || Loss: 4.5571 || 10iter: 15.9026 sec.
# イテレーション 3340 || Loss: 4.7509 || 10iter: 15.7866 sec.
# イテレーション 3350 || Loss: 5.0548 || 10iter: 15.8801 sec.
# イテレーション 3360 || Loss: 4.7040 || 10iter: 15.9730 sec.
# イテレーション 3370 || Loss: 4.6417 || 10iter: 16.0506 sec.
# イテレーション 3380 || Loss: 5.0645 || 10iter: 15.6970 sec.
# イテレーション 3390 || Loss: 4.3196 || 10iter: 16.1792 sec.
# イテレーション 3400 || Loss: 4.8040 || 10iter: 16.1902 sec.
# -------------
# epoch 19 || Epoch_TRAIN_Loss:818.1401 ||Epoch_VAL_Loss:0.0000
# timer:  296.0842 sec.
# -------------
# Epoch 20/50
# -------------
# （train）
# イテレーション 3410 || Loss: 4.6404 || 10iter: 14.1125 sec.
# イテレーション 3420 || Loss: 4.2923 || 10iter: 15.8001 sec.
# イテレーション 3430 || Loss: 4.1527 || 10iter: 16.0762 sec.
# イテレーション 3440 || Loss: 4.4182 || 10iter: 16.1806 sec.
# イテレーション 3450 || Loss: 4.7789 || 10iter: 16.1289 sec.
# イテレーション 3460 || Loss: 4.5223 || 10iter: 15.8842 sec.
# イテレーション 3470 || Loss: 4.7965 || 10iter: 15.7903 sec.
# イテレーション 3480 || Loss: 4.2842 || 10iter: 15.8841 sec.
# イテレーション 3490 || Loss: 4.5195 || 10iter: 15.7084 sec.
# イテレーション 3500 || Loss: 4.2766 || 10iter: 16.0154 sec.
# イテレーション 3510 || Loss: 4.7227 || 10iter: 16.0905 sec.
# イテレーション 3520 || Loss: 4.4684 || 10iter: 15.9558 sec.
# イテレーション 3530 || Loss: 4.0559 || 10iter: 15.8990 sec.
# イテレーション 3540 || Loss: 4.8291 || 10iter: 15.9472 sec.
# イテレーション 3550 || Loss: 4.2178 || 10iter: 15.7757 sec.
# イテレーション 3560 || Loss: 4.4347 || 10iter: 15.9060 sec.
# イテレーション 3570 || Loss: 4.7011 || 10iter: 15.9279 sec.
# イテレーション 3580 || Loss: 4.8517 || 10iter: 15.7055 sec.
# -------------
# （val）
# -------------
# epoch 20 || Epoch_TRAIN_Loss:809.3092 ||Epoch_VAL_Loss:822.5590
# timer:  420.6129 sec.
# -------------
# Epoch 21/50
# -------------
# （train）
# イテレーション 3590 || Loss: 3.9357 || 10iter: 15.8328 sec.
# イテレーション 3600 || Loss: 4.4815 || 10iter: 15.9292 sec.
# イテレーション 3610 || Loss: 4.2734 || 10iter: 15.8451 sec.
# イテレーション 3620 || Loss: 4.3263 || 10iter: 15.7568 sec.
# イテレーション 3630 || Loss: 4.1394 || 10iter: 15.8905 sec.
# イテレーション 3640 || Loss: 3.8830 || 10iter: 15.8139 sec.
# イテレーション 3650 || Loss: 4.2699 || 10iter: 15.9781 sec.
# イテレーション 3660 || Loss: 4.3559 || 10iter: 15.8664 sec.
# イテレーション 3670 || Loss: 4.3688 || 10iter: 15.9800 sec.
# イテレーション 3680 || Loss: 3.9314 || 10iter: 15.7771 sec.
# イテレーション 3690 || Loss: 4.6088 || 10iter: 15.8975 sec.
# イテレーション 3700 || Loss: 4.2820 || 10iter: 15.8807 sec.
# イテレーション 3710 || Loss: 4.6732 || 10iter: 15.8622 sec.
# イテレーション 3720 || Loss: 5.2025 || 10iter: 15.7543 sec.
# イテレーション 3730 || Loss: 4.5337 || 10iter: 15.8453 sec.
# イテレーション 3740 || Loss: 4.5748 || 10iter: 15.7792 sec.
# イテレーション 3750 || Loss: 4.6142 || 10iter: 16.0393 sec.
# -------------
# epoch 21 || Epoch_TRAIN_Loss:791.3232 ||Epoch_VAL_Loss:0.0000
# timer:  295.3480 sec.
# -------------
# Epoch 22/50
# -------------
# （train）
# イテレーション 3760 || Loss: 4.2238 || 10iter: 0.9580 sec.
# イテレーション 3770 || Loss: 4.2178 || 10iter: 15.6545 sec.
# イテレーション 3780 || Loss: 4.1493 || 10iter: 15.9533 sec.
# イテレーション 3790 || Loss: 4.4923 || 10iter: 15.8796 sec.
# イテレーション 3800 || Loss: 4.1669 || 10iter: 15.8638 sec.
# イテレーション 3810 || Loss: 4.4236 || 10iter: 15.9179 sec.
# イテレーション 3820 || Loss: 4.7016 || 10iter: 16.0923 sec.
# イテレーション 3830 || Loss: 3.7937 || 10iter: 16.0679 sec.
# イテレーション 3840 || Loss: 4.6528 || 10iter: 15.7967 sec.
# イテレーション 3850 || Loss: 4.4299 || 10iter: 15.6734 sec.
# イテレーション 3860 || Loss: 4.2878 || 10iter: 15.8837 sec.
# イテレーション 3870 || Loss: 4.4340 || 10iter: 15.7555 sec.
# イテレーション 3880 || Loss: 4.0107 || 10iter: 15.8286 sec.
# イテレーション 3890 || Loss: 4.5927 || 10iter: 15.8595 sec.
# イテレーション 3900 || Loss: 3.8552 || 10iter: 15.8863 sec.
# イテレーション 3910 || Loss: 4.6556 || 10iter: 15.9450 sec.
# イテレーション 3920 || Loss: 4.6197 || 10iter: 16.0097 sec.
# イテレーション 3930 || Loss: 4.0746 || 10iter: 15.7884 sec.
# -------------
# epoch 22 || Epoch_TRAIN_Loss:789.5846 ||Epoch_VAL_Loss:0.0000
# timer:  294.9838 sec.
# -------------
# Epoch 23/50
# -------------
# （train）
# イテレーション 3940 || Loss: 3.6356 || 10iter: 2.6668 sec.
# イテレーション 3950 || Loss: 4.3191 || 10iter: 15.8794 sec.
# イテレーション 3960 || Loss: 4.4194 || 10iter: 15.8745 sec.
# イテレーション 3970 || Loss: 4.1763 || 10iter: 16.0582 sec.
# イテレーション 3980 || Loss: 4.8727 || 10iter: 16.0939 sec.
# イテレーション 3990 || Loss: 3.9027 || 10iter: 15.7469 sec.
# イテレーション 4000 || Loss: 4.6995 || 10iter: 15.9906 sec.
# イテレーション 4010 || Loss: 4.6684 || 10iter: 15.6854 sec.
# イテレーション 4020 || Loss: 4.8814 || 10iter: 15.8562 sec.
# イテレーション 4030 || Loss: 4.3785 || 10iter: 15.8572 sec.
# イテレーション 4040 || Loss: 4.3271 || 10iter: 15.8538 sec.
# イテレーション 4050 || Loss: 5.1005 || 10iter: 16.1171 sec.
# イテレーション 4060 || Loss: 4.3952 || 10iter: 15.7636 sec.
# イテレーション 4070 || Loss: 4.5688 || 10iter: 15.7823 sec.
# イテレーション 4080 || Loss: 4.2253 || 10iter: 15.9488 sec.
# イテレーション 4090 || Loss: 3.8484 || 10iter: 15.8357 sec.
# イテレーション 4100 || Loss: 4.4094 || 10iter: 15.8546 sec.
# イテレーション 4110 || Loss: 4.1698 || 10iter: 15.7704 sec.
# -------------
# epoch 23 || Epoch_TRAIN_Loss:776.3608 ||Epoch_VAL_Loss:0.0000
# timer:  295.2008 sec.
# -------------
# Epoch 24/50
# -------------
# （train）
# イテレーション 4120 || Loss: 4.7723 || 10iter: 4.2236 sec.
# イテレーション 4130 || Loss: 4.0332 || 10iter: 15.9406 sec.
# イテレーション 4140 || Loss: 4.4158 || 10iter: 15.9060 sec.
# イテレーション 4150 || Loss: 4.1181 || 10iter: 15.7356 sec.
# イテレーション 4160 || Loss: 4.5441 || 10iter: 15.9659 sec.
# イテレーション 4170 || Loss: 4.0193 || 10iter: 15.8730 sec.
# イテレーション 4180 || Loss: 4.4727 || 10iter: 16.1759 sec.
# イテレーション 4190 || Loss: 4.9798 || 10iter: 15.8474 sec.
# イテレーション 4200 || Loss: 4.5937 || 10iter: 15.8699 sec.
# イテレーション 4210 || Loss: 4.3283 || 10iter: 15.8997 sec.
# イテレーション 4220 || Loss: 4.0106 || 10iter: 15.7410 sec.
# イテレーション 4230 || Loss: 4.9211 || 10iter: 15.9720 sec.
# イテレーション 4240 || Loss: 4.6394 || 10iter: 15.8226 sec.
# イテレーション 4250 || Loss: 3.7911 || 10iter: 15.5134 sec.
# イテレーション 4260 || Loss: 4.2872 || 10iter: 15.6603 sec.
# イテレーション 4270 || Loss: 4.7211 || 10iter: 15.6112 sec.
# イテレーション 4280 || Loss: 4.3783 || 10iter: 15.7810 sec.
# イテレーション 4290 || Loss: 3.8662 || 10iter: 16.0651 sec.
# -------------
# epoch 24 || Epoch_TRAIN_Loss:766.6094 ||Epoch_VAL_Loss:0.0000
# timer:  294.7729 sec.
# -------------
# Epoch 25/50
# -------------
# （train）
# イテレーション 4300 || Loss: 3.9111 || 10iter: 5.9521 sec.
# イテレーション 4310 || Loss: 4.1259 || 10iter: 16.0841 sec.
# イテレーション 4320 || Loss: 3.7390 || 10iter: 16.0480 sec.
# イテレーション 4330 || Loss: 3.9486 || 10iter: 15.5040 sec.
# イテレーション 4340 || Loss: 4.0128 || 10iter: 15.9537 sec.
# イテレーション 4350 || Loss: 4.2491 || 10iter: 15.7823 sec.
# イテレーション 4360 || Loss: 4.3775 || 10iter: 15.5977 sec.
# イテレーション 4370 || Loss: 4.6318 || 10iter: 15.6617 sec.
# イテレーション 4380 || Loss: 4.5954 || 10iter: 15.9533 sec.
# イテレーション 4390 || Loss: 4.0397 || 10iter: 15.9248 sec.
# イテレーション 4400 || Loss: 4.0192 || 10iter: 15.8649 sec.
# イテレーション 4410 || Loss: 3.8006 || 10iter: 15.6126 sec.
# イテレーション 4420 || Loss: 4.2384 || 10iter: 15.8732 sec.
# イテレーション 4430 || Loss: 3.9278 || 10iter: 15.8708 sec.
# イテレーション 4440 || Loss: 4.5870 || 10iter: 16.2509 sec.
# イテレーション 4450 || Loss: 4.0919 || 10iter: 15.9807 sec.
# イテレーション 4460 || Loss: 3.8869 || 10iter: 16.0473 sec.
# イテレーション 4470 || Loss: 4.2373 || 10iter: 15.3783 sec.
# -------------
# epoch 25 || Epoch_TRAIN_Loss:756.3100 ||Epoch_VAL_Loss:0.0000
# timer:  294.7785 sec.
# -------------
# Epoch 26/50
# -------------
# （train）
# イテレーション 4480 || Loss: 4.0340 || 10iter: 7.6327 sec.
# イテレーション 4490 || Loss: 4.0407 || 10iter: 15.8907 sec.
# イテレーション 4500 || Loss: 4.0021 || 10iter: 15.7281 sec.
# イテレーション 4510 || Loss: 4.0314 || 10iter: 15.9083 sec.
# イテレーション 4520 || Loss: 4.2269 || 10iter: 15.4687 sec.
# イテレーション 4530 || Loss: 4.1301 || 10iter: 15.8100 sec.
# イテレーション 4540 || Loss: 4.2545 || 10iter: 16.0481 sec.
# イテレーション 4550 || Loss: 3.7324 || 10iter: 15.8747 sec.
# イテレーション 4560 || Loss: 4.3561 || 10iter: 15.8752 sec.
# イテレーション 4570 || Loss: 4.0895 || 10iter: 15.7114 sec.
# イテレーション 4580 || Loss: 3.8345 || 10iter: 15.8140 sec.
# イテレーション 4590 || Loss: 4.1360 || 10iter: 15.6910 sec.
# イテレーション 4600 || Loss: 4.8274 || 10iter: 16.0076 sec.
# イテレーション 4610 || Loss: 4.0515 || 10iter: 15.6998 sec.
# イテレーション 4620 || Loss: 3.8387 || 10iter: 15.8565 sec.
# イテレーション 4630 || Loss: 4.4173 || 10iter: 15.6181 sec.
# イテレーション 4640 || Loss: 3.7834 || 10iter: 15.9975 sec.
# イテレーション 4650 || Loss: 3.9373 || 10iter: 15.7774 sec.
# -------------
# epoch 26 || Epoch_TRAIN_Loss:748.5928 ||Epoch_VAL_Loss:0.0000
# timer:  294.2924 sec.
# -------------
# Epoch 27/50
# -------------
# （train）
# イテレーション 4660 || Loss: 4.2943 || 10iter: 9.1504 sec.
# イテレーション 4670 || Loss: 4.0374 || 10iter: 15.6199 sec.
# イテレーション 4680 || Loss: 4.2807 || 10iter: 16.1264 sec.
# イテレーション 4690 || Loss: 4.1905 || 10iter: 15.7844 sec.
# イテレーション 4700 || Loss: 3.8977 || 10iter: 15.8143 sec.
# イテレーション 4710 || Loss: 3.9833 || 10iter: 15.7641 sec.
# イテレーション 4720 || Loss: 3.7327 || 10iter: 15.6613 sec.
# イテレーション 4730 || Loss: 4.9232 || 10iter: 15.8032 sec.
# イテレーション 4740 || Loss: 4.1931 || 10iter: 15.8021 sec.
# イテレーション 4750 || Loss: 4.1183 || 10iter: 15.6924 sec.
# イテレーション 4760 || Loss: 4.6288 || 10iter: 15.9174 sec.
# イテレーション 4770 || Loss: 3.9077 || 10iter: 15.9727 sec.
# イテレーション 4780 || Loss: 4.2069 || 10iter: 16.2026 sec.
# イテレーション 4790 || Loss: 4.3513 || 10iter: 15.8870 sec.
# イテレーション 4800 || Loss: 4.0969 || 10iter: 15.7971 sec.
# イテレーション 4810 || Loss: 4.1721 || 10iter: 16.2439 sec.
# イテレーション 4820 || Loss: 4.5888 || 10iter: 16.1379 sec.
# イテレーション 4830 || Loss: 4.4869 || 10iter: 16.0908 sec.
# -------------
# epoch 27 || Epoch_TRAIN_Loss:740.7420 ||Epoch_VAL_Loss:0.0000
# timer:  295.5378 sec.
# -------------
# Epoch 28/50
# -------------
# （train）
# イテレーション 4840 || Loss: 3.9987 || 10iter: 10.8064 sec.
# イテレーション 4850 || Loss: 4.0164 || 10iter: 15.8376 sec.
# イテレーション 4860 || Loss: 3.8247 || 10iter: 15.8496 sec.
# イテレーション 4870 || Loss: 4.3066 || 10iter: 15.8878 sec.
# イテレーション 4880 || Loss: 3.8426 || 10iter: 15.8227 sec.
# イテレーション 4890 || Loss: 4.1809 || 10iter: 16.1001 sec.
# イテレーション 4900 || Loss: 4.1532 || 10iter: 15.9815 sec.
# イテレーション 4910 || Loss: 4.0449 || 10iter: 15.4769 sec.
# イテレーション 4920 || Loss: 3.9427 || 10iter: 15.9916 sec.
# イテレーション 4930 || Loss: 3.7778 || 10iter: 15.5099 sec.
# イテレーション 4940 || Loss: 4.1214 || 10iter: 15.6345 sec.
# イテレーション 4950 || Loss: 4.5348 || 10iter: 15.8255 sec.
# イテレーション 4960 || Loss: 3.8377 || 10iter: 15.9260 sec.
# イテレーション 4970 || Loss: 4.1818 || 10iter: 16.0504 sec.
# イテレーション 4980 || Loss: 3.9931 || 10iter: 16.0134 sec.
# イテレーション 4990 || Loss: 4.0114 || 10iter: 15.7099 sec.
# イテレーション 5000 || Loss: 4.1176 || 10iter: 16.0913 sec.
# イテレーション 5010 || Loss: 3.5251 || 10iter: 16.2152 sec.
# -------------
# epoch 28 || Epoch_TRAIN_Loss:734.1647 ||Epoch_VAL_Loss:0.0000
# timer:  295.1643 sec.
# -------------
# Epoch 29/50
# -------------
# （train）
# イテレーション 5020 || Loss: 4.4010 || 10iter: 12.9922 sec.
# イテレーション 5030 || Loss: 4.1612 || 10iter: 15.9864 sec.
# イテレーション 5040 || Loss: 4.5797 || 10iter: 15.6510 sec.
# イテレーション 5050 || Loss: 3.9494 || 10iter: 15.8005 sec.
# イテレーション 5060 || Loss: 4.2604 || 10iter: 15.9065 sec.
# イテレーション 5070 || Loss: 4.9464 || 10iter: 15.8994 sec.
# イテレーション 5080 || Loss: 3.6373 || 10iter: 16.0360 sec.
# イテレーション 5090 || Loss: 3.8572 || 10iter: 15.7106 sec.
# イテレーション 5100 || Loss: 4.3611 || 10iter: 16.1211 sec.
# イテレーション 5110 || Loss: 4.0867 || 10iter: 16.0349 sec.
# イテレーション 5120 || Loss: 4.3061 || 10iter: 15.7324 sec.
# イテレーション 5130 || Loss: 3.8421 || 10iter: 15.9595 sec.
# イテレーション 5140 || Loss: 3.7177 || 10iter: 15.7763 sec.
# イテレーション 5150 || Loss: 4.2952 || 10iter: 16.0235 sec.
# イテレーション 5160 || Loss: 3.6451 || 10iter: 15.9573 sec.
# イテレーション 5170 || Loss: 4.3056 || 10iter: 15.8867 sec.
# イテレーション 5180 || Loss: 4.2264 || 10iter: 15.8466 sec.
# イテレーション 5190 || Loss: 3.9565 || 10iter: 16.2378 sec.
# -------------
# epoch 29 || Epoch_TRAIN_Loss:725.6180 ||Epoch_VAL_Loss:0.0000
# timer:  296.4849 sec.
# -------------
# Epoch 30/50
# -------------
# （train）
# イテレーション 5200 || Loss: 4.2413 || 10iter: 14.3404 sec.
# イテレーション 5210 || Loss: 3.5357 || 10iter: 15.9824 sec.
# イテレーション 5220 || Loss: 3.9238 || 10iter: 16.0078 sec.
# イテレーション 5230 || Loss: 3.4018 || 10iter: 16.0204 sec.
# イテレーション 5240 || Loss: 3.8694 || 10iter: 16.0501 sec.
# イテレーション 5250 || Loss: 3.5767 || 10iter: 16.0097 sec.
# イテレーション 5260 || Loss: 4.0344 || 10iter: 15.7512 sec.
# イテレーション 5270 || Loss: 4.3836 || 10iter: 15.8469 sec.
# イテレーション 5280 || Loss: 3.7900 || 10iter: 16.0368 sec.
# イテレーション 5290 || Loss: 3.9484 || 10iter: 15.6591 sec.
# イテレーション 5300 || Loss: 3.3664 || 10iter: 15.9606 sec.
# イテレーション 5310 || Loss: 4.3326 || 10iter: 15.7512 sec.
# イテレーション 5320 || Loss: 3.4970 || 10iter: 16.0884 sec.
# イテレーション 5330 || Loss: 4.0944 || 10iter: 15.7918 sec.
# イテレーション 5340 || Loss: 3.8664 || 10iter: 15.7408 sec.
# イテレーション 5350 || Loss: 4.1754 || 10iter: 15.9034 sec.
# イテレーション 5360 || Loss: 4.2864 || 10iter: 15.9595 sec.
# イテレーション 5370 || Loss: 4.0572 || 10iter: 15.8219 sec.
# -------------
# （val）
# -------------
# epoch 30 || Epoch_TRAIN_Loss:714.4757 ||Epoch_VAL_Loss:758.8694
# timer:  419.8854 sec.
# -------------
# Epoch 31/50
# -------------
# （train）
# イテレーション 5380 || Loss: 3.3887 || 10iter: 15.9919 sec.
# イテレーション 5390 || Loss: 3.1102 || 10iter: 16.1561 sec.
# イテレーション 5400 || Loss: 4.2847 || 10iter: 15.7546 sec.
# イテレーション 5410 || Loss: 3.7334 || 10iter: 15.6352 sec.
# イテレーション 5420 || Loss: 3.8130 || 10iter: 15.9152 sec.
# イテレーション 5430 || Loss: 4.4258 || 10iter: 15.6350 sec.
# イテレーション 5440 || Loss: 3.9134 || 10iter: 15.7989 sec.
# イテレーション 5450 || Loss: 3.7743 || 10iter: 16.0846 sec.
# イテレーション 5460 || Loss: 4.3924 || 10iter: 15.8743 sec.
# イテレーション 5470 || Loss: 3.9922 || 10iter: 15.5739 sec.
# イテレーション 5480 || Loss: 3.7041 || 10iter: 15.4937 sec.
# イテレーション 5490 || Loss: 4.0651 || 10iter: 15.8277 sec.
# イテレーション 5500 || Loss: 4.2797 || 10iter: 16.0539 sec.
# イテレーション 5510 || Loss: 3.7132 || 10iter: 15.8878 sec.
# イテレーション 5520 || Loss: 4.0430 || 10iter: 15.8430 sec.
# イテレーション 5530 || Loss: 4.0392 || 10iter: 15.7331 sec.
# イテレーション 5540 || Loss: 3.8418 || 10iter: 16.1211 sec.
# -------------
# epoch 31 || Epoch_TRAIN_Loss:712.1561 ||Epoch_VAL_Loss:0.0000
# timer:  294.6766 sec.
# -------------
# Epoch 32/50
# -------------
# （train）
# イテレーション 5550 || Loss: 4.2348 || 10iter: 1.0896 sec.
# イテレーション 5560 || Loss: 3.7770 || 10iter: 15.5774 sec.
# イテレーション 5570 || Loss: 3.1150 || 10iter: 15.5347 sec.
# イテレーション 5580 || Loss: 4.1128 || 10iter: 15.8615 sec.
# イテレーション 5590 || Loss: 3.9439 || 10iter: 15.5313 sec.
# イテレーション 5600 || Loss: 4.0356 || 10iter: 15.9230 sec.
# イテレーション 5610 || Loss: 4.1772 || 10iter: 16.0363 sec.
# イテレーション 5620 || Loss: 4.1416 || 10iter: 15.9087 sec.
# イテレーション 5630 || Loss: 3.8224 || 10iter: 16.0152 sec.
# イテレーション 5640 || Loss: 4.3022 || 10iter: 15.9667 sec.
# イテレーション 5650 || Loss: 4.3416 || 10iter: 15.8438 sec.
# イテレーション 5660 || Loss: 4.0065 || 10iter: 15.7733 sec.
# イテレーション 5670 || Loss: 3.8037 || 10iter: 15.8672 sec.
# イテレーション 5680 || Loss: 4.0158 || 10iter: 16.4332 sec.
# イテレーション 5690 || Loss: 3.7902 || 10iter: 16.0943 sec.
# イテレーション 5700 || Loss: 3.9382 || 10iter: 16.0848 sec.
# イテレーション 5710 || Loss: 4.0519 || 10iter: 16.0818 sec.
# イテレーション 5720 || Loss: 4.1910 || 10iter: 16.1348 sec.
# -------------
# epoch 32 || Epoch_TRAIN_Loss:709.0904 ||Epoch_VAL_Loss:0.0000
# timer:  296.0527 sec.
# -------------
# Epoch 33/50
# -------------
# （train）
# イテレーション 5730 || Loss: 3.9101 || 10iter: 2.6870 sec.
# イテレーション 5740 || Loss: 3.7113 || 10iter: 15.8179 sec.
# イテレーション 5750 || Loss: 3.7691 || 10iter: 15.7136 sec.
# イテレーション 5760 || Loss: 3.5019 || 10iter: 15.7969 sec.
# イテレーション 5770 || Loss: 4.0236 || 10iter: 16.1178 sec.
# イテレーション 5780 || Loss: 3.8168 || 10iter: 15.6706 sec.
# イテレーション 5790 || Loss: 3.7056 || 10iter: 15.7683 sec.
# イテレーション 5800 || Loss: 3.6951 || 10iter: 15.8987 sec.
# イテレーション 5810 || Loss: 4.6237 || 10iter: 16.0425 sec.
# イテレーション 5820 || Loss: 3.9071 || 10iter: 16.2653 sec.
# イテレーション 5830 || Loss: 4.1102 || 10iter: 16.1387 sec.
# イテレーション 5840 || Loss: 3.4735 || 10iter: 15.9215 sec.
# イテレーション 5850 || Loss: 3.8546 || 10iter: 15.8964 sec.
# イテレーション 5860 || Loss: 4.2797 || 10iter: 16.1309 sec.
# イテレーション 5870 || Loss: 3.6206 || 10iter: 15.4764 sec.
# イテレーション 5880 || Loss: 4.2645 || 10iter: 16.2699 sec.
# イテレーション 5890 || Loss: 3.5196 || 10iter: 16.1489 sec.
# イテレーション 5900 || Loss: 4.2631 || 10iter: 15.8221 sec.
# -------------
# epoch 33 || Epoch_TRAIN_Loss:694.6566 ||Epoch_VAL_Loss:0.0000
# timer:  296.2769 sec.
# -------------
# Epoch 34/50
# -------------
# （train）
# イテレーション 5910 || Loss: 4.0843 || 10iter: 4.2482 sec.
# イテレーション 5920 || Loss: 4.1017 || 10iter: 15.9918 sec.
# イテレーション 5930 || Loss: 3.5244 || 10iter: 15.7860 sec.
# イテレーション 5940 || Loss: 4.1443 || 10iter: 15.7195 sec.
# イテレーション 5950 || Loss: 4.3530 || 10iter: 15.7968 sec.
# イテレーション 5960 || Loss: 3.4618 || 10iter: 16.0586 sec.
# イテレーション 5970 || Loss: 4.0336 || 10iter: 15.6684 sec.
# イテレーション 5980 || Loss: 4.1312 || 10iter: 15.8861 sec.
# イテレーション 5990 || Loss: 4.6253 || 10iter: 16.0444 sec.
# イテレーション 6000 || Loss: 3.8223 || 10iter: 15.5465 sec.
# イテレーション 6010 || Loss: 4.3530 || 10iter: 15.8183 sec.
# イテレーション 6020 || Loss: 4.0262 || 10iter: 16.0003 sec.
# イテレーション 6030 || Loss: 3.4643 || 10iter: 16.1142 sec.
# イテレーション 6040 || Loss: 4.4352 || 10iter: 15.9756 sec.
# イテレーション 6050 || Loss: 3.9792 || 10iter: 15.8046 sec.
# イテレーション 6060 || Loss: 4.1501 || 10iter: 16.0915 sec.
# イテレーション 6070 || Loss: 3.7137 || 10iter: 15.8023 sec.
# イテレーション 6080 || Loss: 3.5983 || 10iter: 15.8497 sec.
# -------------
# epoch 34 || Epoch_TRAIN_Loss:696.7508 ||Epoch_VAL_Loss:0.0000
# timer:  295.2813 sec.
# -------------
# Epoch 35/50
# -------------
# （train）
# イテレーション 6090 || Loss: 3.9690 || 10iter: 5.9977 sec.
# イテレーション 6100 || Loss: 3.3933 || 10iter: 16.0019 sec.
# イテレーション 6110 || Loss: 3.6672 || 10iter: 15.8505 sec.
# イテレーション 6120 || Loss: 4.0030 || 10iter: 15.7056 sec.
# イテレーション 6130 || Loss: 3.7430 || 10iter: 15.9014 sec.
# イテレーション 6140 || Loss: 4.0216 || 10iter: 15.8875 sec.
# イテレーション 6150 || Loss: 3.8752 || 10iter: 15.7133 sec.
# イテレーション 6160 || Loss: 3.8231 || 10iter: 15.7711 sec.
# イテレーション 6170 || Loss: 3.7261 || 10iter: 15.9328 sec.
# イテレーション 6180 || Loss: 4.1934 || 10iter: 16.1620 sec.
# イテレーション 6190 || Loss: 3.4995 || 10iter: 15.9833 sec.
# イテレーション 6200 || Loss: 3.7469 || 10iter: 15.5783 sec.
# イテレーション 6210 || Loss: 4.2219 || 10iter: 15.7413 sec.
# イテレーション 6220 || Loss: 3.6336 || 10iter: 15.9835 sec.
# イテレーション 6230 || Loss: 3.4884 || 10iter: 15.9461 sec.
# イテレーション 6240 || Loss: 3.6433 || 10iter: 16.0404 sec.
# イテレーション 6250 || Loss: 3.8811 || 10iter: 16.1317 sec.
# イテレーション 6260 || Loss: 4.0987 || 10iter: 15.9677 sec.
# -------------
# epoch 35 || Epoch_TRAIN_Loss:688.5841 ||Epoch_VAL_Loss:0.0000
# timer:  295.6529 sec.
# -------------
# Epoch 36/50
# -------------
# （train）
# イテレーション 6270 || Loss: 3.9725 || 10iter: 7.7151 sec.
# イテレーション 6280 || Loss: 4.1632 || 10iter: 15.9366 sec.
# イテレーション 6290 || Loss: 3.3744 || 10iter: 16.0022 sec.
# イテレーション 6300 || Loss: 3.6740 || 10iter: 15.8371 sec.
# イテレーション 6310 || Loss: 3.7056 || 10iter: 15.9937 sec.
# イテレーション 6320 || Loss: 3.9214 || 10iter: 16.0848 sec.
# イテレーション 6330 || Loss: 3.7194 || 10iter: 15.9979 sec.
# イテレーション 6340 || Loss: 4.5286 || 10iter: 15.9274 sec.
# イテレーション 6350 || Loss: 3.7266 || 10iter: 16.2040 sec.
# イテレーション 6360 || Loss: 4.0591 || 10iter: 15.9893 sec.
# イテレーション 6370 || Loss: 3.5375 || 10iter: 15.8993 sec.
# イテレーション 6380 || Loss: 3.7609 || 10iter: 16.0030 sec.
# イテレーション 6390 || Loss: 4.0653 || 10iter: 15.7252 sec.
# イテレーション 6400 || Loss: 3.7122 || 10iter: 15.8082 sec.
# イテレーション 6410 || Loss: 3.6325 || 10iter: 16.2069 sec.
# イテレーション 6420 || Loss: 4.7146 || 10iter: 15.7607 sec.
# イテレーション 6430 || Loss: 3.5262 || 10iter: 16.0173 sec.
# イテレーション 6440 || Loss: 3.6587 || 10iter: 15.8158 sec.
# -------------
# epoch 36 || Epoch_TRAIN_Loss:682.1883 ||Epoch_VAL_Loss:0.0000
# timer:  296.8137 sec.
# -------------
# Epoch 37/50
# -------------
# （train）
# イテレーション 6450 || Loss: 3.1493 || 10iter: 9.4489 sec.
# イテレーション 6460 || Loss: 3.6937 || 10iter: 15.5848 sec.
# イテレーション 6470 || Loss: 3.7606 || 10iter: 15.9572 sec.
# イテレーション 6480 || Loss: 3.5785 || 10iter: 16.1270 sec.
# イテレーション 6490 || Loss: 3.8472 || 10iter: 15.9638 sec.
# イテレーション 6500 || Loss: 4.1971 || 10iter: 15.9117 sec.
# イテレーション 6510 || Loss: 3.5208 || 10iter: 15.9661 sec.
# イテレーション 6520 || Loss: 3.3217 || 10iter: 15.8601 sec.
# イテレーション 6530 || Loss: 3.8129 || 10iter: 15.8935 sec.
# イテレーション 6540 || Loss: 3.9277 || 10iter: 16.2431 sec.
# イテレーション 6550 || Loss: 3.0872 || 10iter: 15.9067 sec.
# イテレーション 6560 || Loss: 3.8320 || 10iter: 15.6827 sec.
# イテレーション 6570 || Loss: 3.5154 || 10iter: 15.8980 sec.
# イテレーション 6580 || Loss: 3.6703 || 10iter: 15.9441 sec.
# イテレーション 6590 || Loss: 3.6878 || 10iter: 16.3251 sec.
# イテレーション 6600 || Loss: 3.5815 || 10iter: 15.9465 sec.
# イテレーション 6610 || Loss: 4.4247 || 10iter: 16.2135 sec.
# イテレーション 6620 || Loss: 3.7564 || 10iter: 15.8198 sec.
# -------------
# epoch 37 || Epoch_TRAIN_Loss:682.1636 ||Epoch_VAL_Loss:0.0000
# timer:  296.8292 sec.
# -------------
# Epoch 38/50
# -------------
# （train）
# イテレーション 6630 || Loss: 3.7478 || 10iter: 11.1306 sec.
# イテレーション 6640 || Loss: 3.4125 || 10iter: 16.3309 sec.
# イテレーション 6650 || Loss: 3.9661 || 10iter: 15.9849 sec.
# イテレーション 6660 || Loss: 3.8857 || 10iter: 15.7950 sec.
# イテレーション 6670 || Loss: 3.6757 || 10iter: 16.0861 sec.
# イテレーション 6680 || Loss: 3.6916 || 10iter: 15.9731 sec.
# イテレーション 6690 || Loss: 4.0536 || 10iter: 15.7714 sec.
# イテレーション 6700 || Loss: 4.0781 || 10iter: 15.9974 sec.
# イテレーション 6710 || Loss: 4.0626 || 10iter: 15.8120 sec.
# イテレーション 6720 || Loss: 3.9340 || 10iter: 16.1305 sec.
# イテレーション 6730 || Loss: 4.0362 || 10iter: 16.0636 sec.
# イテレーション 6740 || Loss: 3.9280 || 10iter: 15.7354 sec.
# イテレーション 6750 || Loss: 3.3376 || 10iter: 15.8648 sec.
# イテレーション 6760 || Loss: 4.0508 || 10iter: 16.1734 sec.
# イテレーション 6770 || Loss: 3.9005 || 10iter: 15.7932 sec.
# イテレーション 6780 || Loss: 3.6184 || 10iter: 15.5734 sec.
# イテレーション 6790 || Loss: 3.9997 || 10iter: 15.9554 sec.
# イテレーション 6800 || Loss: 3.8558 || 10iter: 15.8996 sec.
# -------------
# epoch 38 || Epoch_TRAIN_Loss:675.7282 ||Epoch_VAL_Loss:0.0000
# timer:  296.6443 sec.
# -------------
# Epoch 39/50
# -------------
# （train）
# イテレーション 6810 || Loss: 3.5330 || 10iter: 12.7389 sec.
# イテレーション 6820 || Loss: 3.3426 || 10iter: 16.0053 sec.
# イテレーション 6830 || Loss: 3.2309 || 10iter: 16.0175 sec.
# イテレーション 6840 || Loss: 4.0657 || 10iter: 15.8558 sec.
# イテレーション 6850 || Loss: 3.7423 || 10iter: 16.1338 sec.
# イテレーション 6860 || Loss: 4.0585 || 10iter: 16.1021 sec.
# イテレーション 6870 || Loss: 3.8367 || 10iter: 15.8022 sec.
# イテレーション 6880 || Loss: 3.7889 || 10iter: 16.1106 sec.
# イテレーション 6890 || Loss: 4.3277 || 10iter: 15.9536 sec.
# イテレーション 6900 || Loss: 3.6859 || 10iter: 16.1979 sec.
# イテレーション 6910 || Loss: 4.0047 || 10iter: 15.9255 sec.
# イテレーション 6920 || Loss: 4.1146 || 10iter: 15.9430 sec.
# イテレーション 6930 || Loss: 3.7321 || 10iter: 16.3678 sec.
# イテレーション 6940 || Loss: 3.7263 || 10iter: 16.1443 sec.
# イテレーション 6950 || Loss: 3.0078 || 10iter: 15.9501 sec.
# イテレーション 6960 || Loss: 3.8623 || 10iter: 15.8439 sec.
# イテレーション 6970 || Loss: 3.9642 || 10iter: 16.0054 sec.
# イテレーション 6980 || Loss: 3.5177 || 10iter: 15.8119 sec.
# -------------
# epoch 39 || Epoch_TRAIN_Loss:664.4769 ||Epoch_VAL_Loss:0.0000
# timer:  297.6837 sec.
# -------------
# Epoch 40/50
# -------------
# （train）
# イテレーション 6990 || Loss: 3.9432 || 10iter: 14.2758 sec.
# イテレーション 7000 || Loss: 4.0925 || 10iter: 15.8935 sec.
# イテレーション 7010 || Loss: 4.0994 || 10iter: 16.1782 sec.
# イテレーション 7020 || Loss: 3.5452 || 10iter: 15.9208 sec.
# イテレーション 7030 || Loss: 3.6040 || 10iter: 15.7803 sec.
# イテレーション 7040 || Loss: 3.2308 || 10iter: 15.8152 sec.
# イテレーション 7050 || Loss: 3.7199 || 10iter: 15.9913 sec.
# イテレーション 7060 || Loss: 3.7306 || 10iter: 16.0358 sec.
# イテレーション 7070 || Loss: 3.3619 || 10iter: 15.8065 sec.
# イテレーション 7080 || Loss: 3.8929 || 10iter: 15.8665 sec.
# イテレーション 7090 || Loss: 3.1657 || 10iter: 15.7860 sec.
# イテレーション 7100 || Loss: 3.8650 || 10iter: 15.9790 sec.
# イテレーション 7110 || Loss: 3.4050 || 10iter: 16.0791 sec.
# イテレーション 7120 || Loss: 4.0422 || 10iter: 15.7457 sec.
# イテレーション 7130 || Loss: 3.9787 || 10iter: 15.8710 sec.
# イテレーション 7140 || Loss: 3.9385 || 10iter: 16.0212 sec.
# イテレーション 7150 || Loss: 3.2620 || 10iter: 16.0296 sec.
# イテレーション 7160 || Loss: 4.0150 || 10iter: 15.4714 sec.
# -------------
# （val）
# -------------
# epoch 40 || Epoch_TRAIN_Loss:659.4403 ||Epoch_VAL_Loss:723.7701
# timer:  420.5857 sec.
# -------------
# Epoch 41/50
# -------------
# （train）
# イテレーション 7170 || Loss: 3.5310 || 10iter: 16.1891 sec.
# イテレーション 7180 || Loss: 3.8005 || 10iter: 16.2205 sec.
# イテレーション 7190 || Loss: 3.9118 || 10iter: 15.5925 sec.
# イテレーション 7200 || Loss: 3.8698 || 10iter: 15.9363 sec.
# イテレーション 7210 || Loss: 3.3259 || 10iter: 15.8423 sec.
# イテレーション 7220 || Loss: 4.4164 || 10iter: 16.1553 sec.
# イテレーション 7230 || Loss: 3.5616 || 10iter: 15.7294 sec.
# イテレーション 7240 || Loss: 3.5991 || 10iter: 15.8056 sec.
# イテレーション 7250 || Loss: 3.8648 || 10iter: 15.9763 sec.
# イテレーション 7260 || Loss: 3.6605 || 10iter: 15.9351 sec.
# イテレーション 7270 || Loss: 3.1400 || 10iter: 15.7477 sec.
# イテレーション 7280 || Loss: 3.4270 || 10iter: 15.9567 sec.
# イテレーション 7290 || Loss: 3.9308 || 10iter: 15.8340 sec.
# イテレーション 7300 || Loss: 3.9911 || 10iter: 15.8279 sec.
# イテレーション 7310 || Loss: 3.7321 || 10iter: 16.1936 sec.
# イテレーション 7320 || Loss: 4.1966 || 10iter: 15.7387 sec.
# イテレーション 7330 || Loss: 3.9855 || 10iter: 15.8879 sec.
# -------------
# epoch 41 || Epoch_TRAIN_Loss:650.5882 ||Epoch_VAL_Loss:0.0000
# timer:  295.7089 sec.
# -------------
# Epoch 42/50
# -------------
# （train）
# イテレーション 7340 || Loss: 3.6170 || 10iter: 1.0040 sec.
# イテレーション 7350 || Loss: 3.3893 || 10iter: 15.9856 sec.
# イテレーション 7360 || Loss: 3.7267 || 10iter: 16.0065 sec.
# イテレーション 7370 || Loss: 3.7246 || 10iter: 15.9902 sec.
# イテレーション 7380 || Loss: 3.5507 || 10iter: 16.0082 sec.
# イテレーション 7390 || Loss: 3.5505 || 10iter: 15.8155 sec.
# イテレーション 7400 || Loss: 3.5583 || 10iter: 15.8574 sec.
# イテレーション 7410 || Loss: 3.8941 || 10iter: 15.6988 sec.
# イテレーション 7420 || Loss: 3.4937 || 10iter: 15.9205 sec.
# イテレーション 7430 || Loss: 3.1963 || 10iter: 15.9654 sec.
# イテレーション 7440 || Loss: 3.3810 || 10iter: 16.0081 sec.
# イテレーション 7450 || Loss: 4.0139 || 10iter: 16.1417 sec.
# イテレーション 7460 || Loss: 4.0631 || 10iter: 15.9271 sec.
# イテレーション 7470 || Loss: 3.4225 || 10iter: 15.9360 sec.
# イテレーション 7480 || Loss: 3.5390 || 10iter: 16.0862 sec.
# イテレーション 7490 || Loss: 3.7701 || 10iter: 15.8039 sec.
# イテレーション 7500 || Loss: 3.0839 || 10iter: 15.7888 sec.
# イテレーション 7510 || Loss: 3.7862 || 10iter: 16.1744 sec.
# -------------
# epoch 42 || Epoch_TRAIN_Loss:654.7504 ||Epoch_VAL_Loss:0.0000
# timer:  296.4100 sec.
# -------------
# Epoch 43/50
# -------------
# （train）
# イテレーション 7520 || Loss: 4.0762 || 10iter: 2.6052 sec.
# イテレーション 7530 || Loss: 3.6495 || 10iter: 15.8797 sec.
# イテレーション 7540 || Loss: 3.4408 || 10iter: 15.9713 sec.
# イテレーション 7550 || Loss: 3.2584 || 10iter: 15.8557 sec.
# イテレーション 7560 || Loss: 3.8222 || 10iter: 15.6843 sec.
# イテレーション 7570 || Loss: 3.4154 || 10iter: 16.0862 sec.
# イテレーション 7580 || Loss: 3.8343 || 10iter: 16.0027 sec.
# イテレーション 7590 || Loss: 3.6478 || 10iter: 16.1804 sec.
# イテレーション 7600 || Loss: 3.6191 || 10iter: 16.2161 sec.
# イテレーション 7610 || Loss: 3.1437 || 10iter: 15.8107 sec.
# イテレーション 7620 || Loss: 3.7898 || 10iter: 16.0870 sec.
# イテレーション 7630 || Loss: 3.2589 || 10iter: 15.9824 sec.
# イテレーション 7640 || Loss: 3.1174 || 10iter: 16.2370 sec.
# イテレーション 7650 || Loss: 3.2053 || 10iter: 15.6946 sec.
# イテレーション 7660 || Loss: 2.8969 || 10iter: 15.8061 sec.
# イテレーション 7670 || Loss: 4.2819 || 10iter: 15.9964 sec.
# イテレーション 7680 || Loss: 4.1291 || 10iter: 15.9369 sec.
# イテレーション 7690 || Loss: 2.8516 || 10iter: 15.9687 sec.
# -------------
# epoch 43 || Epoch_TRAIN_Loss:650.6436 ||Epoch_VAL_Loss:0.0000
# timer:  297.0342 sec.
# -------------
# Epoch 44/50
# -------------
# （train）
# イテレーション 7700 || Loss: 3.2808 || 10iter: 4.2954 sec.
# イテレーション 7710 || Loss: 3.8156 || 10iter: 16.0942 sec.
# イテレーション 7720 || Loss: 3.0428 || 10iter: 15.9411 sec.
# イテレーション 7730 || Loss: 2.9580 || 10iter: 15.7685 sec.
# イテレーション 7740 || Loss: 4.0415 || 10iter: 15.8563 sec.
# イテレーション 7750 || Loss: 3.6014 || 10iter: 15.9980 sec.
# イテレーション 7760 || Loss: 3.3385 || 10iter: 15.9926 sec.
# イテレーション 7770 || Loss: 3.8004 || 10iter: 15.9648 sec.
# イテレーション 7780 || Loss: 3.3901 || 10iter: 16.0409 sec.
# イテレーション 7790 || Loss: 3.2606 || 10iter: 15.9501 sec.
# イテレーション 7800 || Loss: 3.6651 || 10iter: 15.6634 sec.
# イテレーション 7810 || Loss: 3.8312 || 10iter: 15.8797 sec.
# イテレーション 7820 || Loss: 3.4822 || 10iter: 15.8731 sec.
# イテレーション 7830 || Loss: 4.0046 || 10iter: 15.7648 sec.
# イテレーション 7840 || Loss: 3.8665 || 10iter: 16.0428 sec.
# イテレーション 7850 || Loss: 3.7850 || 10iter: 16.1119 sec.
# イテレーション 7860 || Loss: 3.9356 || 10iter: 16.0105 sec.
# イテレーション 7870 || Loss: 3.5900 || 10iter: 16.1727 sec.
# -------------
# epoch 44 || Epoch_TRAIN_Loss:641.0876 ||Epoch_VAL_Loss:0.0000
# timer:  296.6433 sec.
# -------------
# Epoch 45/50
# -------------
# （train）
# イテレーション 7880 || Loss: 3.8966 || 10iter: 6.0310 sec.
# イテレーション 7890 || Loss: 3.6747 || 10iter: 15.6785 sec.
# イテレーション 7900 || Loss: 3.3812 || 10iter: 15.9745 sec.
# イテレーション 7910 || Loss: 4.1101 || 10iter: 16.1276 sec.
# イテレーション 7920 || Loss: 4.2384 || 10iter: 15.8048 sec.
# イテレーション 7930 || Loss: 3.6521 || 10iter: 15.8377 sec.
# イテレーション 7940 || Loss: 4.0058 || 10iter: 15.8813 sec.
# イテレーション 7950 || Loss: 3.7488 || 10iter: 15.8534 sec.
# イテレーション 7960 || Loss: 3.8083 || 10iter: 15.9088 sec.
# イテレーション 7970 || Loss: 3.9590 || 10iter: 16.1291 sec.
# イテレーション 7980 || Loss: 3.3619 || 10iter: 16.0077 sec.
# イテレーション 7990 || Loss: 2.9834 || 10iter: 15.8149 sec.
# イテレーション 8000 || Loss: 3.4610 || 10iter: 15.9190 sec.
# イテレーション 8010 || Loss: 3.5487 || 10iter: 15.6900 sec.
# イテレーション 8020 || Loss: 3.3924 || 10iter: 15.8411 sec.
# イテレーション 8030 || Loss: 3.6594 || 10iter: 16.1882 sec.
# イテレーション 8040 || Loss: 3.2162 || 10iter: 16.0340 sec.
# イテレーション 8050 || Loss: 3.5826 || 10iter: 15.4546 sec.
# -------------
# epoch 45 || Epoch_TRAIN_Loss:638.5607 ||Epoch_VAL_Loss:0.0000
# timer:  295.7177 sec.
# -------------
# Epoch 46/50
# -------------
# （train）
# イテレーション 8060 || Loss: 4.0471 || 10iter: 7.6536 sec.
# イテレーション 8070 || Loss: 3.4361 || 10iter: 16.0230 sec.
# イテレーション 8080 || Loss: 3.1885 || 10iter: 15.7075 sec.
# イテレーション 8090 || Loss: 3.4129 || 10iter: 16.0960 sec.
# イテレーション 8100 || Loss: 3.6769 || 10iter: 15.7173 sec.
# イテレーション 8110 || Loss: 3.6171 || 10iter: 16.1421 sec.
# イテレーション 8120 || Loss: 3.2955 || 10iter: 15.8508 sec.
# イテレーション 8130 || Loss: 3.2309 || 10iter: 15.8202 sec.
# イテレーション 8140 || Loss: 3.2791 || 10iter: 15.8298 sec.
# イテレーション 8150 || Loss: 3.2615 || 10iter: 16.3078 sec.
# イテレーション 8160 || Loss: 3.6580 || 10iter: 15.7606 sec.
# イテレーション 8170 || Loss: 3.5072 || 10iter: 15.9059 sec.
# イテレーション 8180 || Loss: 3.1763 || 10iter: 15.9818 sec.
# イテレーション 8190 || Loss: 3.9274 || 10iter: 15.7859 sec.
# イテレーション 8200 || Loss: 3.4222 || 10iter: 16.0844 sec.
# イテレーション 8210 || Loss: 3.4665 || 10iter: 15.6179 sec.
# イテレーション 8220 || Loss: 3.6073 || 10iter: 16.0205 sec.
# イテレーション 8230 || Loss: 3.9622 || 10iter: 16.0173 sec.
# -------------
# epoch 46 || Epoch_TRAIN_Loss:634.2959 ||Epoch_VAL_Loss:0.0000
# timer:  296.0295 sec.
# -------------
# Epoch 47/50
# -------------
# （train）
# イテレーション 8240 || Loss: 3.1457 || 10iter: 9.5742 sec.
# イテレーション 8250 || Loss: 3.4946 || 10iter: 16.0262 sec.
# イテレーション 8260 || Loss: 3.6400 || 10iter: 16.2246 sec.
# イテレーション 8270 || Loss: 3.5874 || 10iter: 15.8813 sec.
# イテレーション 8280 || Loss: 3.6548 || 10iter: 16.0650 sec.
# イテレーション 8290 || Loss: 3.5781 || 10iter: 15.9165 sec.
# イテレーション 8300 || Loss: 4.2570 || 10iter: 16.1755 sec.
# イテレーション 8310 || Loss: 3.1871 || 10iter: 15.7170 sec.
# イテレーション 8320 || Loss: 4.0176 || 10iter: 16.1581 sec.
# イテレーション 8330 || Loss: 3.5407 || 10iter: 16.1309 sec.
# イテレーション 8340 || Loss: 3.9559 || 10iter: 16.1863 sec.
# イテレーション 8350 || Loss: 3.8380 || 10iter: 16.0245 sec.
# イテレーション 8360 || Loss: 3.5157 || 10iter: 16.0614 sec.
# イテレーション 8370 || Loss: 3.5534 || 10iter: 15.8819 sec.
# イテレーション 8380 || Loss: 3.0684 || 10iter: 16.0301 sec.
# イテレーション 8390 || Loss: 3.9529 || 10iter: 15.8029 sec.
# イテレーション 8400 || Loss: 3.3017 || 10iter: 16.1831 sec.
# イテレーション 8410 || Loss: 3.3467 || 10iter: 15.6223 sec.
# -------------
# epoch 47 || Epoch_TRAIN_Loss:635.2971 ||Epoch_VAL_Loss:0.0000
# timer:  297.7911 sec.
# -------------
# Epoch 48/50
# -------------
# （train）
# イテレーション 8420 || Loss: 3.1926 || 10iter: 11.0627 sec.
# イテレーション 8430 || Loss: 3.6285 || 10iter: 15.8947 sec.
# イテレーション 8440 || Loss: 4.2012 || 10iter: 15.8388 sec.
# イテレーション 8450 || Loss: 3.4367 || 10iter: 16.0193 sec.
# イテレーション 8460 || Loss: 3.8533 || 10iter: 15.9137 sec.
# イテレーション 8470 || Loss: 3.7095 || 10iter: 15.8922 sec.
# イテレーション 8480 || Loss: 3.2764 || 10iter: 15.6906 sec.
# イテレーション 8490 || Loss: 3.0093 || 10iter: 15.9787 sec.
# イテレーション 8500 || Loss: 3.8069 || 10iter: 16.0649 sec.
# イテレーション 8510 || Loss: 3.0810 || 10iter: 16.1232 sec.
# イテレーション 8520 || Loss: 3.4232 || 10iter: 16.1345 sec.
# イテレーション 8530 || Loss: 3.6352 || 10iter: 15.8136 sec.
# イテレーション 8540 || Loss: 3.6608 || 10iter: 15.5608 sec.
# イテレーション 8550 || Loss: 3.5522 || 10iter: 16.2896 sec.
# イテレーション 8560 || Loss: 4.4700 || 10iter: 16.1391 sec.
# イテレーション 8570 || Loss: 3.1158 || 10iter: 15.8637 sec.
# イテレーション 8580 || Loss: 3.6000 || 10iter: 15.8324 sec.
# イテレーション 8590 || Loss: 3.4568 || 10iter: 15.9511 sec.
# -------------
# epoch 48 || Epoch_TRAIN_Loss:629.3946 ||Epoch_VAL_Loss:0.0000
# timer:  296.6437 sec.
# -------------
# Epoch 49/50
# -------------
# （train）
# イテレーション 8600 || Loss: 3.9235 || 10iter: 12.7514 sec.
# イテレーション 8610 || Loss: 3.3199 || 10iter: 15.6815 sec.
# イテレーション 8620 || Loss: 3.5538 || 10iter: 15.7259 sec.
# イテレーション 8630 || Loss: 3.6793 || 10iter: 15.7929 sec.
# イテレーション 8640 || Loss: 3.1526 || 10iter: 15.8216 sec.
# イテレーション 8650 || Loss: 3.6529 || 10iter: 15.8888 sec.
# イテレーション 8660 || Loss: 3.2828 || 10iter: 15.8477 sec.
# イテレーション 8670 || Loss: 3.4815 || 10iter: 15.7897 sec.
# イテレーション 8680 || Loss: 3.6631 || 10iter: 15.9631 sec.
# イテレーション 8690 || Loss: 4.0384 || 10iter: 15.9664 sec.
# イテレーション 8700 || Loss: 3.3276 || 10iter: 15.7559 sec.
# イテレーション 8710 || Loss: 3.8242 || 10iter: 15.7159 sec.
# イテレーション 8720 || Loss: 3.9384 || 10iter: 15.8704 sec.
# イテレーション 8730 || Loss: 3.2455 || 10iter: 15.9549 sec.
# イテレーション 8740 || Loss: 3.4535 || 10iter: 16.3252 sec.
# イテレーション 8750 || Loss: 3.1756 || 10iter: 15.6884 sec.
# イテレーション 8760 || Loss: 3.7011 || 10iter: 15.9034 sec.
# イテレーション 8770 || Loss: 3.1743 || 10iter: 15.7546 sec.
# -------------
# epoch 49 || Epoch_TRAIN_Loss:622.7283 ||Epoch_VAL_Loss:0.0000
# timer:  295.0316 sec.
# -------------
# Epoch 50/50
# -------------
# （train）
# イテレーション 8780 || Loss: 3.2052 || 10iter: 14.2071 sec.
# イテレーション 8790 || Loss: 3.6421 || 10iter: 16.0615 sec.
# イテレーション 8800 || Loss: 3.6000 || 10iter: 16.0547 sec.
# イテレーション 8810 || Loss: 3.8459 || 10iter: 16.0744 sec.
# イテレーション 8820 || Loss: 3.8386 || 10iter: 16.2317 sec.
# イテレーション 8830 || Loss: 2.9110 || 10iter: 16.0854 sec.
# イテレーション 8840 || Loss: 4.0367 || 10iter: 15.9601 sec.
# イテレーション 8850 || Loss: 3.3204 || 10iter: 15.8140 sec.
# イテレーション 8860 || Loss: 3.4893 || 10iter: 15.9356 sec.
# イテレーション 8870 || Loss: 3.7925 || 10iter: 16.0214 sec.
# イテレーション 8880 || Loss: 3.5915 || 10iter: 15.8532 sec.
# イテレーション 8890 || Loss: 3.6164 || 10iter: 15.8624 sec.
# イテレーション 8900 || Loss: 3.5774 || 10iter: 16.1102 sec.
# イテレーション 8910 || Loss: 3.7596 || 10iter: 15.8332 sec.
# イテレーション 8920 || Loss: 3.4927 || 10iter: 15.6244 sec.
# イテレーション 8930 || Loss: 3.2601 || 10iter: 15.8778 sec.
# イテレーション 8940 || Loss: 3.3108 || 10iter: 15.9458 sec.
# イテレーション 8950 || Loss: 3.4235 || 10iter: 15.8147 sec.
# -------------
# （val）
# -------------
# epoch 50 || Epoch_TRAIN_Loss:620.2345 ||Epoch_VAL_Loss:702.1665
# timer:  421.1734 sec.
# -------------
# Epoch 51/50
# -------------
# （train）
# イテレーション 8960 || Loss: 3.3559 || 10iter: 16.2199 sec.
# イテレーション 8970 || Loss: 3.1709 || 10iter: 15.9039 sec.
# イテレーション 8980 || Loss: 3.8937 || 10iter: 15.8863 sec.
# イテレーション 8990 || Loss: 3.8964 || 10iter: 15.9106 sec.
# イテレーション 9000 || Loss: 3.2652 || 10iter: 15.9142 sec.
# イテレーション 9010 || Loss: 3.5339 || 10iter: 15.8508 sec.
# イテレーション 9020 || Loss: 3.4659 || 10iter: 16.0410 sec.
# イテレーション 9030 || Loss: 3.3093 || 10iter: 15.6807 sec.
# イテレーション 9040 || Loss: 3.7469 || 10iter: 15.9163 sec.
# イテレーション 9050 || Loss: 3.5350 || 10iter: 16.0822 sec.
# イテレーション 9060 || Loss: 2.9843 || 10iter: 15.7471 sec.
# イテレーション 9070 || Loss: 3.7425 || 10iter: 15.8485 sec.
# イテレーション 9080 || Loss: 3.2846 || 10iter: 15.8242 sec.
# イテレーション 9090 || Loss: 3.8881 || 10iter: 15.6796 sec.
# イテレーション 9100 || Loss: 3.2312 || 10iter: 15.8603 sec.
# イテレーション 9110 || Loss: 3.6536 || 10iter: 16.2958 sec.
# イテレーション 9120 || Loss: 3.2211 || 10iter: 15.7227 sec.
# -------------
# epoch 51 || Epoch_TRAIN_Loss:617.7066 ||Epoch_VAL_Loss:0.0000
# timer:  295.7221 sec.

# %% [markdown]
# 以上
