# %% [markdown]
# # 5.4 SAGANの作成
#
# - 本ファイルでは、Self-Attention GANのネットワークを実装と学習をします。

# %% [markdown]
# # 5.4 学習目標
#
# 1.	SAGANを実装できるようになる

# %% [markdown]
# # 事前準備
# 書籍の指示に従い、本章で使用するデータを用意します

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd "/content/drive/My Drive/Colab Notebooks/pytorch_advanced/5_gan_generation"
# Out:
# /content/drive/My Drive/Colab Notebooks/pytorch_advanced/5_gan_generation

# %%
# パッケージのimport
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # Self-Attentionモジュールの実装

# %%
class Self_Attention(nn.Module):
    """ Self-AttentionのLayer"""

    def __init__(self, in_dim):
        super(Self_Attention, self).__init__()

        # 1×1の畳み込み層によるpointwise convolutionを用意
        self.query_conv = nn.Conv2d(
            in_channels=in_dim, out_channels=in_dim//8, kernel_size=1)
        self.key_conv = nn.Conv2d(
            in_channels=in_dim, out_channels=in_dim//8, kernel_size=1)
        self.value_conv = nn.Conv2d(
            in_channels=in_dim, out_channels=in_dim, kernel_size=1)

        # Attention Map作成時の規格化のソフトマックス
        self.softmax = nn.Softmax(dim=-2)

        # 元の入力xとSelf-Attention Mapであるoを足し算するときの係数
        # output = x +gamma*o
        # 最初はgamma=0で、学習させていく
        self.gamma = nn.Parameter(torch.zeros(1))

    def forward(self, x):

        # 入力変数
        X = x

        # 畳み込みをしてから、サイズを変形する。 B,C',W,H→B,C',N へ
        proj_query = self.query_conv(X).view(
            X.shape[0], -1, X.shape[2]*X.shape[3])  # サイズ：B,C',N
        proj_query = proj_query.permute(0, 2, 1)  # 転置操作
        proj_key = self.key_conv(X).view(
            X.shape[0], -1, X.shape[2]*X.shape[3])  # サイズ：B,C',N

        # かけ算
        S = torch.bmm(proj_query, proj_key)  # bmmはバッチごとの行列かけ算です

        # 規格化
        attention_map_T = self.softmax(S)  # 行i方向の和を1にするソフトマックス関数
        attention_map = attention_map_T.permute(0, 2, 1)  # 転置をとる

        # Self-Attention Mapを計算する
        proj_value = self.value_conv(X).view(
            X.shape[0], -1, X.shape[2]*X.shape[3])  # サイズ：B,C,N
        o = torch.bmm(proj_value, attention_map.permute(
            0, 2, 1))  # Attention Mapは転置してかけ算

        # Self-Attention MapであるoのテンソルサイズをXにそろえて、出力にする
        o = o.view(X.shape[0], X.shape[1], X.shape[2], X.shape[3])
        out = x+self.gamma*o

        return out, attention_map

# %% [markdown]
# # Generatorの実装

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.ConvTranspose2d(z_dim, image_size * 8,
                                                      kernel_size=4, stride=1)),
            nn.BatchNorm2d(image_size * 8),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size * 8, image_size * 4,
                                                      kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size * 4),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size * 4, image_size * 2,
                                                      kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size * 2),
            nn.ReLU(inplace=True))

        # Self-Attentin層を追加
        self.self_attntion1 = Self_Attention(in_dim=image_size * 2)

        self.layer4 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size * 2, image_size,
                                                      kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size),
            nn.ReLU(inplace=True))

        # Self-Attentin層を追加
        self.self_attntion2 = Self_Attention(in_dim=image_size)

        self.last = nn.Sequential(
            nn.ConvTranspose2d(image_size, 1, kernel_size=4,
                               stride=2, padding=1),
            nn.Tanh())
        # 注意：白黒画像なので出力チャネルは1つだけ


    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)
        out = self.layer3(out)
        out, attention_map1 = self.self_attntion1(out)
        out = self.layer4(out)
        out, attention_map2 = self.self_attntion2(out)
        out = self.last(out)

        return out, attention_map1, attention_map2

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20, image_size=64)

# 入力する乱数
input_z = torch.randn(1, 20)

# テンソルサイズを(1, 20, 1, 1)に変形
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

# 偽画像を出力
fake_images, attention_map1, attention_map2 = G(input_z)

img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %% [markdown]
# # Discriminatorの実装

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Discriminator, self).__init__()

        self.layer1 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.Conv2d(1, image_size, kernel_size=4,
                                             stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.layer2 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.Conv2d(image_size, image_size*2, kernel_size=4,
                                             stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.Conv2d(image_size*2, image_size*4, kernel_size=4,
                                             stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))

        # Self-Attentin層を追加
        self.self_attntion1 = Self_Attention(in_dim=image_size*4)

        self.layer4 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.Conv2d(image_size*4, image_size*8, kernel_size=4,
                                             stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))

        # Self-Attentin層を追加
        self.self_attntion2 = Self_Attention(in_dim=image_size*8)

        self.last = nn.Conv2d(image_size*8, 1, kernel_size=4, stride=1)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out, attention_map1 = self.self_attntion1(out)
        out = self.layer4(out)
        out, attention_map2 = self.self_attntion2(out)
        out = self.last(out)

        return out, attention_map1, attention_map2

# %%
# 動作確認
D = Discriminator(z_dim=20, image_size=64)

# 偽画像を生成
input_z = torch.randn(1, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images, _, _ = G(input_z)

# 偽画像をDに入力
d_out, attention_map1, attention_map2 = D(fake_images)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[[[0.5001]]]], grad_fn=<SigmoidBackward>)

# %% [markdown]
# # DataLoaderの作成

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./../data/img_78/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./../data/img_78/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''前処理をした画像のTensor形式のデータを取得'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list=make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 64, 64])

# %% [markdown]
# # 学習させる

# %%
# モデルを学習させる関数を作成


def train_model(G, D, dataloader, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # 最適化手法の設定
    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])

    # 誤差関数を定義 → hinge version of the adversarial lossに変更
    # criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # パラメータをハードコーディング
    z_dim = 20
    mini_batch_size = 64

    # ネットワークをGPUへ
    G.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # 画像の枚数
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # イテレーションカウンタをセット
    iteration = 1
    logs = []

    # epochのループ
    for epoch in range(num_epochs):

        # 開始時刻を保存
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epochの損失和
        epoch_d_loss = 0.0  # epochの損失和

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('（train）')

        # データローダーからminibatchずつ取り出すループ
        for imges in dataloader:

            # --------------------
            # 1. Discriminatorの学習
            # --------------------
            # ミニバッチがサイズが1だと、バッチノーマライゼーションでエラーになるのでさける
            if imges.size()[0] == 1:
                continue

            # GPUが使えるならGPUにデータを送る
            imges = imges.to(device)

            # 正解ラベルと偽ラベルを作成
            # epochの最後のイテレーションはミニバッチの数が少なくなる
            mini_batch_size = imges.size()[0]
            #label_real = torch.full((mini_batch_size,), 1).to(device)
            #label_fake = torch.full((mini_batch_size,), 0).to(device)

            # 真の画像を判定
            d_out_real, _, _ = D(imges)

            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images, _, _ = G(input_z)
            d_out_fake, _, _ = D(fake_images)

            # 誤差を計算→hinge version of the adversarial lossに変更
            # d_loss_real = criterion(d_out_real.view(-1), label_real)
            # d_loss_fake = criterion(d_out_fake.view(-1), label_fake)

            d_loss_real = torch.nn.ReLU()(1.0 - d_out_real).mean()
            # 誤差　d_out_realが1以上で誤差0になる。d_out_real>1で、
            # 1.0 - d_out_realが負の場合ReLUで0にする

            d_loss_fake = torch.nn.ReLU()(1.0 + d_out_fake).mean()
            # 誤差　d_out_fakeが-1以下なら誤差0になる。d_out_fake<-1で、
            # 1.0 + d_out_realが負の場合ReLUで0にする

            d_loss = d_loss_real + d_loss_fake

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()

            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generatorの学習
            # --------------------
            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images, _, _ = G(input_z)
            d_out_fake, _, _ = D(fake_images)

            # 誤差を計算→hinge version of the adversarial lossに変更
            #g_loss = criterion(d_out_fake.view(-1), label_real)
            g_loss = - d_out_fake.mean()

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. 記録
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    # print("総イテレーション回数:", iteration)

    return G, D

# %%
# ネットワークの初期化
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # Conv2dとConvTranspose2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2dの初期化
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


# 初期化の実施
G.apply(weights_init)
D.apply(weights_init)

print("ネットワークの初期化完了")
# Out:
# ネットワークの初期化完了

# %%
# 学習・検証を実行する
# 15分ほどかかる
num_epochs = 300
G_update, D_update = train_model(
    G, D, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 0/300
# -------------
# （train）
# -------------
# epoch 0 || Epoch_D_Loss:0.1507 ||Epoch_G_Loss:0.0791
# timer:  79.0732 sec.
# -------------
# Epoch 1/300
# -------------
# （train）
# -------------
# epoch 1 || Epoch_D_Loss:0.1208 ||Epoch_G_Loss:0.0659
# timer:  1.4564 sec.
# -------------
# Epoch 2/300
# -------------
# （train）
# -------------
# epoch 2 || Epoch_D_Loss:0.1187 ||Epoch_G_Loss:0.0107
# timer:  1.4717 sec.
# -------------
# Epoch 3/300
# -------------
# （train）
# -------------
# epoch 3 || Epoch_D_Loss:0.1271 ||Epoch_G_Loss:0.0156
# timer:  1.5149 sec.
# -------------
# Epoch 4/300
# -------------
# （train）
# -------------
# epoch 4 || Epoch_D_Loss:0.0690 ||Epoch_G_Loss:0.0719
# timer:  1.4917 sec.
# -------------
# Epoch 5/300
# -------------
# （train）
# -------------
# epoch 5 || Epoch_D_Loss:0.0001 ||Epoch_G_Loss:0.1278
# timer:  1.4293 sec.
# -------------
# Epoch 6/300
# -------------
# （train）
# -------------
# epoch 6 || Epoch_D_Loss:0.1277 ||Epoch_G_Loss:0.1022
# timer:  1.4849 sec.
# -------------
# Epoch 7/300
# -------------
# （train）
# -------------
# epoch 7 || Epoch_D_Loss:0.0006 ||Epoch_G_Loss:0.1304
# timer:  1.4546 sec.
# -------------
# Epoch 8/300
# -------------
# （train）
# -------------
# epoch 8 || Epoch_D_Loss:0.0794 ||Epoch_G_Loss:0.0718
# timer:  1.4649 sec.
# -------------
# Epoch 9/300
# -------------
# （train）
# -------------
# epoch 9 || Epoch_D_Loss:0.0351 ||Epoch_G_Loss:0.1327
# timer:  1.4558 sec.
# -------------
# Epoch 10/300
# -------------
# （train）
# -------------
# epoch 10 || Epoch_D_Loss:0.0916 ||Epoch_G_Loss:0.1141
# timer:  1.4647 sec.
# -------------
# Epoch 11/300
# -------------
# （train）
# -------------
# epoch 11 || Epoch_D_Loss:0.0768 ||Epoch_G_Loss:0.0730
# timer:  1.4717 sec.
# -------------
# Epoch 12/300
# -------------
# （train）
# -------------
# epoch 12 || Epoch_D_Loss:0.0844 ||Epoch_G_Loss:0.0829
# timer:  1.4846 sec.
# -------------
# Epoch 13/300
# -------------
# （train）
# -------------
# epoch 13 || Epoch_D_Loss:0.0514 ||Epoch_G_Loss:0.1116
# timer:  1.4683 sec.
# -------------
# Epoch 14/300
# -------------
# （train）
# -------------
# epoch 14 || Epoch_D_Loss:0.0651 ||Epoch_G_Loss:0.1091
# timer:  1.4661 sec.
# -------------
# Epoch 15/300
# -------------
# （train）
# -------------
# epoch 15 || Epoch_D_Loss:0.0771 ||Epoch_G_Loss:0.1023
# timer:  1.4684 sec.
# -------------
# Epoch 16/300
# -------------
# （train）
# -------------
# epoch 16 || Epoch_D_Loss:0.0901 ||Epoch_G_Loss:0.1125
# timer:  1.5079 sec.
# -------------
# Epoch 17/300
# -------------
# （train）
# -------------
# epoch 17 || Epoch_D_Loss:0.0698 ||Epoch_G_Loss:0.1046
# timer:  1.5186 sec.
# -------------
# Epoch 18/300
# -------------
# （train）
# -------------
# epoch 18 || Epoch_D_Loss:0.0937 ||Epoch_G_Loss:0.1134
# timer:  1.4914 sec.
# -------------
# Epoch 19/300
# -------------
# （train）
# -------------
# epoch 19 || Epoch_D_Loss:0.1117 ||Epoch_G_Loss:0.0853
# timer:  1.5250 sec.
# -------------
# Epoch 20/300
# -------------
# （train）
# -------------
# epoch 20 || Epoch_D_Loss:0.1121 ||Epoch_G_Loss:0.0770
# timer:  1.4873 sec.
# -------------
# Epoch 21/300
# -------------
# （train）
# -------------
# epoch 21 || Epoch_D_Loss:0.1070 ||Epoch_G_Loss:0.0628
# timer:  1.4944 sec.
# -------------
# Epoch 22/300
# -------------
# （train）
# -------------
# epoch 22 || Epoch_D_Loss:0.1118 ||Epoch_G_Loss:0.0920
# timer:  1.5178 sec.
# -------------
# Epoch 23/300
# -------------
# （train）
# -------------
# epoch 23 || Epoch_D_Loss:0.1076 ||Epoch_G_Loss:0.0654
# timer:  1.5338 sec.
# -------------
# Epoch 24/300
# -------------
# （train）
# -------------
# epoch 24 || Epoch_D_Loss:0.1263 ||Epoch_G_Loss:0.0291
# timer:  1.5263 sec.
# -------------
# Epoch 25/300
# -------------
# （train）
# -------------
# epoch 25 || Epoch_D_Loss:0.1466 ||Epoch_G_Loss:0.0680
# timer:  1.5054 sec.
# -------------
# Epoch 26/300
# -------------
# （train）
# -------------
# epoch 26 || Epoch_D_Loss:0.1470 ||Epoch_G_Loss:0.0501
# timer:  1.5404 sec.
# -------------
# Epoch 27/300
# -------------
# （train）
# -------------
# epoch 27 || Epoch_D_Loss:0.1253 ||Epoch_G_Loss:0.0672
# timer:  1.5004 sec.
# -------------
# Epoch 28/300
# -------------
# （train）
# -------------
# epoch 28 || Epoch_D_Loss:0.1633 ||Epoch_G_Loss:-0.0055
# timer:  1.4961 sec.
# -------------
# Epoch 29/300
# -------------
# （train）
# -------------
# epoch 29 || Epoch_D_Loss:0.1723 ||Epoch_G_Loss:0.0257
# timer:  1.4916 sec.
# -------------
# Epoch 30/300
# -------------
# （train）
# -------------
# epoch 30 || Epoch_D_Loss:0.1672 ||Epoch_G_Loss:0.0333
# timer:  1.4919 sec.
# -------------
# Epoch 31/300
# -------------
# （train）
# -------------
# epoch 31 || Epoch_D_Loss:0.1825 ||Epoch_G_Loss:0.0274
# timer:  1.5095 sec.
# -------------
# Epoch 32/300
# -------------
# （train）
# -------------
# epoch 32 || Epoch_D_Loss:0.1697 ||Epoch_G_Loss:0.0551
# timer:  1.4948 sec.
# -------------
# Epoch 33/300
# -------------
# （train）
# -------------
# epoch 33 || Epoch_D_Loss:0.1609 ||Epoch_G_Loss:0.0799
# timer:  1.4994 sec.
# -------------
# Epoch 34/300
# -------------
# （train）
# -------------
# epoch 34 || Epoch_D_Loss:0.1781 ||Epoch_G_Loss:0.0618
# timer:  1.5084 sec.
# -------------
# Epoch 35/300
# -------------
# （train）
# -------------
# epoch 35 || Epoch_D_Loss:0.1960 ||Epoch_G_Loss:-0.0215
# timer:  1.5097 sec.
# -------------
# Epoch 36/300
# -------------
# （train）
# -------------
# epoch 36 || Epoch_D_Loss:0.1727 ||Epoch_G_Loss:0.0538
# timer:  1.5112 sec.
# -------------
# Epoch 37/300
# -------------
# （train）
# -------------
# epoch 37 || Epoch_D_Loss:0.2067 ||Epoch_G_Loss:0.0201
# timer:  1.5199 sec.
# -------------
# Epoch 38/300
# -------------
# （train）
# -------------
# epoch 38 || Epoch_D_Loss:0.1912 ||Epoch_G_Loss:0.0042
# timer:  1.5129 sec.
# -------------
# Epoch 39/300
# -------------
# （train）
# -------------
# epoch 39 || Epoch_D_Loss:0.1806 ||Epoch_G_Loss:0.0284
# timer:  1.5563 sec.
# -------------
# Epoch 40/300
# -------------
# （train）
# -------------
# epoch 40 || Epoch_D_Loss:0.2038 ||Epoch_G_Loss:0.0333
# timer:  1.5111 sec.
# -------------
# Epoch 41/300
# -------------
# （train）
# -------------
# epoch 41 || Epoch_D_Loss:0.1912 ||Epoch_G_Loss:0.0173
# timer:  1.4985 sec.
# -------------
# Epoch 42/300
# -------------
# （train）
# -------------
# epoch 42 || Epoch_D_Loss:0.1858 ||Epoch_G_Loss:0.0410
# timer:  1.5116 sec.
# -------------
# Epoch 43/300
# -------------
# （train）
# -------------
# epoch 43 || Epoch_D_Loss:0.1979 ||Epoch_G_Loss:0.0357
# timer:  1.5113 sec.
# -------------
# Epoch 44/300
# -------------
# （train）
# -------------
# epoch 44 || Epoch_D_Loss:0.1829 ||Epoch_G_Loss:0.0396
# timer:  1.5139 sec.
# -------------
# Epoch 45/300
# -------------
# （train）
# -------------
# epoch 45 || Epoch_D_Loss:0.2025 ||Epoch_G_Loss:0.0408
# timer:  1.5018 sec.
# -------------
# Epoch 46/300
# -------------
# （train）
# -------------
# epoch 46 || Epoch_D_Loss:0.2051 ||Epoch_G_Loss:0.0017
# timer:  1.4982 sec.
# -------------
# Epoch 47/300
# -------------
# （train）
# -------------
# epoch 47 || Epoch_D_Loss:0.1838 ||Epoch_G_Loss:0.0369
# timer:  1.5306 sec.
# -------------
# Epoch 48/300
# -------------
# （train）
# -------------
# epoch 48 || Epoch_D_Loss:0.1840 ||Epoch_G_Loss:0.0246
# timer:  1.5128 sec.
# -------------
# Epoch 49/300
# -------------
# （train）
# -------------
# epoch 49 || Epoch_D_Loss:0.1951 ||Epoch_G_Loss:0.0443
# timer:  1.5181 sec.
# -------------
# Epoch 50/300
# -------------
# （train）
# -------------
# epoch 50 || Epoch_D_Loss:0.1973 ||Epoch_G_Loss:0.0098
# timer:  1.4979 sec.
# -------------
# Epoch 51/300
# -------------
# （train）
# -------------
# epoch 51 || Epoch_D_Loss:0.1767 ||Epoch_G_Loss:0.0575
# timer:  1.5213 sec.
# -------------
# Epoch 52/300
# -------------
# （train）
# -------------
# epoch 52 || Epoch_D_Loss:0.1817 ||Epoch_G_Loss:0.0568
# timer:  1.5061 sec.
# -------------
# Epoch 53/300
# -------------
# （train）
# -------------
# epoch 53 || Epoch_D_Loss:0.1861 ||Epoch_G_Loss:0.0081
# timer:  1.5090 sec.
# -------------
# Epoch 54/300
# -------------
# （train）
# -------------
# epoch 54 || Epoch_D_Loss:0.1772 ||Epoch_G_Loss:0.0523
# timer:  1.5181 sec.
# -------------
# Epoch 55/300
# -------------
# （train）
# -------------
# epoch 55 || Epoch_D_Loss:0.1789 ||Epoch_G_Loss:0.0189
# timer:  1.5164 sec.
# -------------
# Epoch 56/300
# -------------
# （train）
# -------------
# epoch 56 || Epoch_D_Loss:0.1732 ||Epoch_G_Loss:0.0421
# timer:  1.5191 sec.
# -------------
# Epoch 57/300
# -------------
# （train）
# -------------
# epoch 57 || Epoch_D_Loss:0.1796 ||Epoch_G_Loss:0.0145
# timer:  1.4927 sec.
# -------------
# Epoch 58/300
# -------------
# （train）
# -------------
# epoch 58 || Epoch_D_Loss:0.1752 ||Epoch_G_Loss:0.0513
# timer:  1.5530 sec.
# -------------
# Epoch 59/300
# -------------
# （train）
# -------------
# epoch 59 || Epoch_D_Loss:0.1722 ||Epoch_G_Loss:0.0450
# timer:  1.4957 sec.
# -------------
# Epoch 60/300
# -------------
# （train）
# -------------
# epoch 60 || Epoch_D_Loss:0.1760 ||Epoch_G_Loss:0.0161
# timer:  1.5045 sec.
# -------------
# Epoch 61/300
# -------------
# （train）
# -------------
# epoch 61 || Epoch_D_Loss:0.1753 ||Epoch_G_Loss:0.0424
# timer:  1.5336 sec.
# -------------
# Epoch 62/300
# -------------
# （train）
# -------------
# epoch 62 || Epoch_D_Loss:0.1886 ||Epoch_G_Loss:0.0168
# timer:  1.4984 sec.
# -------------
# Epoch 63/300
# -------------
# （train）
# -------------
# epoch 63 || Epoch_D_Loss:0.1928 ||Epoch_G_Loss:0.0203
# timer:  1.5210 sec.
# -------------
# Epoch 64/300
# -------------
# （train）
# -------------
# epoch 64 || Epoch_D_Loss:0.1757 ||Epoch_G_Loss:0.0260
# timer:  1.4992 sec.
# -------------
# Epoch 65/300
# -------------
# （train）
# -------------
# epoch 65 || Epoch_D_Loss:0.1716 ||Epoch_G_Loss:0.0377
# timer:  1.5084 sec.
# -------------
# Epoch 66/300
# -------------
# （train）
# -------------
# epoch 66 || Epoch_D_Loss:0.1781 ||Epoch_G_Loss:0.0390
# timer:  1.5011 sec.
# -------------
# Epoch 67/300
# -------------
# （train）
# -------------
# epoch 67 || Epoch_D_Loss:0.1879 ||Epoch_G_Loss:0.0099
# timer:  1.5082 sec.
# -------------
# Epoch 68/300
# -------------
# （train）
# -------------
# epoch 68 || Epoch_D_Loss:0.1675 ||Epoch_G_Loss:0.0473
# timer:  1.4865 sec.
# -------------
# Epoch 69/300
# -------------
# （train）
# -------------
# epoch 69 || Epoch_D_Loss:0.1829 ||Epoch_G_Loss:0.0241
# timer:  1.4974 sec.
# -------------
# Epoch 70/300
# -------------
# （train）
# -------------
# epoch 70 || Epoch_D_Loss:0.1749 ||Epoch_G_Loss:0.0289
# timer:  1.5003 sec.
# -------------
# Epoch 71/300
# -------------
# （train）
# -------------
# epoch 71 || Epoch_D_Loss:0.1822 ||Epoch_G_Loss:0.0257
# timer:  1.4997 sec.
# -------------
# Epoch 72/300
# -------------
# （train）
# -------------
# epoch 72 || Epoch_D_Loss:0.1788 ||Epoch_G_Loss:0.0298
# timer:  1.4968 sec.
# -------------
# Epoch 73/300
# -------------
# （train）
# -------------
# epoch 73 || Epoch_D_Loss:0.1852 ||Epoch_G_Loss:0.0158
# timer:  1.5090 sec.
# -------------
# Epoch 74/300
# -------------
# （train）
# -------------
# epoch 74 || Epoch_D_Loss:0.1714 ||Epoch_G_Loss:0.0423
# timer:  1.4945 sec.
# -------------
# Epoch 75/300
# -------------
# （train）
# -------------
# epoch 75 || Epoch_D_Loss:0.1738 ||Epoch_G_Loss:0.0383
# timer:  1.5062 sec.
# -------------
# Epoch 76/300
# -------------
# （train）
# -------------
# epoch 76 || Epoch_D_Loss:0.1720 ||Epoch_G_Loss:0.0511
# timer:  1.5362 sec.
# -------------
# Epoch 77/300
# -------------
# （train）
# -------------
# epoch 77 || Epoch_D_Loss:0.1833 ||Epoch_G_Loss:0.0150
# timer:  1.4996 sec.
# -------------
# Epoch 78/300
# -------------
# （train）
# -------------
# epoch 78 || Epoch_D_Loss:0.1743 ||Epoch_G_Loss:0.0385
# timer:  1.5244 sec.
# -------------
# Epoch 79/300
# -------------
# （train）
# -------------
# epoch 79 || Epoch_D_Loss:0.1854 ||Epoch_G_Loss:0.0288
# timer:  1.5008 sec.
# -------------
# Epoch 80/300
# -------------
# （train）
# -------------
# epoch 80 || Epoch_D_Loss:0.1825 ||Epoch_G_Loss:0.0352
# timer:  1.4900 sec.
# -------------
# Epoch 81/300
# -------------
# （train）
# -------------
# epoch 81 || Epoch_D_Loss:0.1537 ||Epoch_G_Loss:0.0421
# timer:  1.5228 sec.
# -------------
# Epoch 82/300
# -------------
# （train）
# -------------
# epoch 82 || Epoch_D_Loss:0.1804 ||Epoch_G_Loss:0.0402
# timer:  1.4907 sec.
# -------------
# Epoch 83/300
# -------------
# （train）
# -------------
# epoch 83 || Epoch_D_Loss:0.1753 ||Epoch_G_Loss:0.0279
# timer:  1.5206 sec.
# -------------
# Epoch 84/300
# -------------
# （train）
# -------------
# epoch 84 || Epoch_D_Loss:0.1680 ||Epoch_G_Loss:0.0337
# timer:  1.5062 sec.
# -------------
# Epoch 85/300
# -------------
# （train）
# -------------
# epoch 85 || Epoch_D_Loss:0.1715 ||Epoch_G_Loss:0.0419
# timer:  1.5133 sec.
# -------------
# Epoch 86/300
# -------------
# （train）
# -------------
# epoch 86 || Epoch_D_Loss:0.1873 ||Epoch_G_Loss:0.0309
# timer:  1.5486 sec.
# -------------
# Epoch 87/300
# -------------
# （train）
# -------------
# epoch 87 || Epoch_D_Loss:0.1795 ||Epoch_G_Loss:0.0422
# timer:  1.5012 sec.
# -------------
# Epoch 88/300
# -------------
# （train）
# -------------
# epoch 88 || Epoch_D_Loss:0.1710 ||Epoch_G_Loss:0.0379
# timer:  1.4947 sec.
# -------------
# Epoch 89/300
# -------------
# （train）
# -------------
# epoch 89 || Epoch_D_Loss:0.1746 ||Epoch_G_Loss:0.0283
# timer:  1.5039 sec.
# -------------
# Epoch 90/300
# -------------
# （train）
# -------------
# epoch 90 || Epoch_D_Loss:0.1680 ||Epoch_G_Loss:0.0472
# timer:  1.5037 sec.
# -------------
# Epoch 91/300
# -------------
# （train）
# -------------
# epoch 91 || Epoch_D_Loss:0.1755 ||Epoch_G_Loss:0.0176
# timer:  1.4978 sec.
# -------------
# Epoch 92/300
# -------------
# （train）
# -------------
# epoch 92 || Epoch_D_Loss:0.1687 ||Epoch_G_Loss:0.0430
# timer:  1.5230 sec.
# -------------
# Epoch 93/300
# -------------
# （train）
# -------------
# epoch 93 || Epoch_D_Loss:0.1706 ||Epoch_G_Loss:0.0401
# timer:  1.4886 sec.
# -------------
# Epoch 94/300
# -------------
# （train）
# -------------
# epoch 94 || Epoch_D_Loss:0.1711 ||Epoch_G_Loss:0.0360
# timer:  1.4939 sec.
# -------------
# Epoch 95/300
# -------------
# （train）
# -------------
# epoch 95 || Epoch_D_Loss:0.1724 ||Epoch_G_Loss:0.0220
# timer:  1.4879 sec.
# -------------
# Epoch 96/300
# -------------
# （train）
# -------------
# epoch 96 || Epoch_D_Loss:0.1807 ||Epoch_G_Loss:0.0275
# timer:  1.5101 sec.
# -------------
# Epoch 97/300
# -------------
# （train）
# -------------
# epoch 97 || Epoch_D_Loss:0.1588 ||Epoch_G_Loss:0.0485
# timer:  1.5015 sec.
# -------------
# Epoch 98/300
# -------------
# （train）
# -------------
# epoch 98 || Epoch_D_Loss:0.1795 ||Epoch_G_Loss:0.0380
# timer:  1.5153 sec.
# -------------
# Epoch 99/300
# -------------
# （train）
# -------------
# epoch 99 || Epoch_D_Loss:0.1693 ||Epoch_G_Loss:0.0438
# timer:  1.5029 sec.
# -------------
# Epoch 100/300
# -------------
# （train）
# -------------
# epoch 100 || Epoch_D_Loss:0.1668 ||Epoch_G_Loss:0.0462
# timer:  1.5046 sec.
# -------------
# Epoch 101/300
# -------------
# （train）
# -------------
# epoch 101 || Epoch_D_Loss:0.1597 ||Epoch_G_Loss:0.0292
# timer:  1.4873 sec.
# -------------
# Epoch 102/300
# -------------
# （train）
# -------------
# epoch 102 || Epoch_D_Loss:0.1662 ||Epoch_G_Loss:0.0563
# timer:  1.4842 sec.
# -------------
# Epoch 103/300
# -------------
# （train）
# -------------
# epoch 103 || Epoch_D_Loss:0.1611 ||Epoch_G_Loss:0.0409
# timer:  1.4847 sec.
# -------------
# Epoch 104/300
# -------------
# （train）
# -------------
# epoch 104 || Epoch_D_Loss:0.1744 ||Epoch_G_Loss:0.0309
# timer:  1.5092 sec.
# -------------
# Epoch 105/300
# -------------
# （train）
# -------------
# epoch 105 || Epoch_D_Loss:0.1626 ||Epoch_G_Loss:0.0410
# timer:  1.4870 sec.
# -------------
# Epoch 106/300
# -------------
# （train）
# -------------
# epoch 106 || Epoch_D_Loss:0.1606 ||Epoch_G_Loss:0.0263
# timer:  1.5050 sec.
# -------------
# Epoch 107/300
# -------------
# （train）
# -------------
# epoch 107 || Epoch_D_Loss:0.1622 ||Epoch_G_Loss:0.0540
# timer:  1.4920 sec.
# -------------
# Epoch 108/300
# -------------
# （train）
# -------------
# epoch 108 || Epoch_D_Loss:0.1538 ||Epoch_G_Loss:0.0706
# timer:  1.5049 sec.
# -------------
# Epoch 109/300
# -------------
# （train）
# -------------
# epoch 109 || Epoch_D_Loss:0.1763 ||Epoch_G_Loss:0.0322
# timer:  1.5025 sec.
# -------------
# Epoch 110/300
# -------------
# （train）
# -------------
# epoch 110 || Epoch_D_Loss:0.1715 ||Epoch_G_Loss:0.0468
# timer:  1.4896 sec.
# -------------
# Epoch 111/300
# -------------
# （train）
# -------------
# epoch 111 || Epoch_D_Loss:0.1599 ||Epoch_G_Loss:0.0413
# timer:  1.5268 sec.
# -------------
# Epoch 112/300
# -------------
# （train）
# -------------
# epoch 112 || Epoch_D_Loss:0.1593 ||Epoch_G_Loss:0.0551
# timer:  1.5144 sec.
# -------------
# Epoch 113/300
# -------------
# （train）
# -------------
# epoch 113 || Epoch_D_Loss:0.1594 ||Epoch_G_Loss:0.0499
# timer:  1.5338 sec.
# -------------
# Epoch 114/300
# -------------
# （train）
# -------------
# epoch 114 || Epoch_D_Loss:0.1611 ||Epoch_G_Loss:0.0439
# timer:  1.4882 sec.
# -------------
# Epoch 115/300
# -------------
# （train）
# -------------
# epoch 115 || Epoch_D_Loss:0.1541 ||Epoch_G_Loss:0.0511
# timer:  1.5204 sec.
# -------------
# Epoch 116/300
# -------------
# （train）
# -------------
# epoch 116 || Epoch_D_Loss:0.1563 ||Epoch_G_Loss:0.0601
# timer:  1.5182 sec.
# -------------
# Epoch 117/300
# -------------
# （train）
# -------------
# epoch 117 || Epoch_D_Loss:0.1727 ||Epoch_G_Loss:0.0463
# timer:  1.5111 sec.
# -------------
# Epoch 118/300
# -------------
# （train）
# -------------
# epoch 118 || Epoch_D_Loss:0.1570 ||Epoch_G_Loss:0.0450
# timer:  1.5162 sec.
# -------------
# Epoch 119/300
# -------------
# （train）
# -------------
# epoch 119 || Epoch_D_Loss:0.1385 ||Epoch_G_Loss:0.0633
# timer:  1.5079 sec.
# -------------
# Epoch 120/300
# -------------
# （train）
# -------------
# epoch 120 || Epoch_D_Loss:0.1649 ||Epoch_G_Loss:0.0511
# timer:  1.5297 sec.
# -------------
# Epoch 121/300
# -------------
# （train）
# -------------
# epoch 121 || Epoch_D_Loss:0.1610 ||Epoch_G_Loss:0.0529
# timer:  1.5001 sec.
# -------------
# Epoch 122/300
# -------------
# （train）
# -------------
# epoch 122 || Epoch_D_Loss:0.1504 ||Epoch_G_Loss:0.0472
# timer:  1.5086 sec.
# -------------
# Epoch 123/300
# -------------
# （train）
# -------------
# epoch 123 || Epoch_D_Loss:0.1592 ||Epoch_G_Loss:0.0635
# timer:  1.4917 sec.
# -------------
# Epoch 124/300
# -------------
# （train）
# -------------
# epoch 124 || Epoch_D_Loss:0.1554 ||Epoch_G_Loss:0.0519
# timer:  1.5116 sec.
# -------------
# Epoch 125/300
# -------------
# （train）
# -------------
# epoch 125 || Epoch_D_Loss:0.1502 ||Epoch_G_Loss:0.0492
# timer:  1.4944 sec.
# -------------
# Epoch 126/300
# -------------
# （train）
# -------------
# epoch 126 || Epoch_D_Loss:0.1535 ||Epoch_G_Loss:0.0613
# timer:  1.5217 sec.
# -------------
# Epoch 127/300
# -------------
# （train）
# -------------
# epoch 127 || Epoch_D_Loss:0.1545 ||Epoch_G_Loss:0.0427
# timer:  1.4922 sec.
# -------------
# Epoch 128/300
# -------------
# （train）
# -------------
# epoch 128 || Epoch_D_Loss:0.1593 ||Epoch_G_Loss:0.0553
# timer:  1.5047 sec.
# -------------
# Epoch 129/300
# -------------
# （train）
# -------------
# epoch 129 || Epoch_D_Loss:0.1505 ||Epoch_G_Loss:0.0613
# timer:  1.4928 sec.
# -------------
# Epoch 130/300
# -------------
# （train）
# -------------
# epoch 130 || Epoch_D_Loss:0.1485 ||Epoch_G_Loss:0.0565
# timer:  1.5032 sec.
# -------------
# Epoch 131/300
# -------------
# （train）
# -------------
# epoch 131 || Epoch_D_Loss:0.1427 ||Epoch_G_Loss:0.0525
# timer:  1.4871 sec.
# -------------
# Epoch 132/300
# -------------
# （train）
# -------------
# epoch 132 || Epoch_D_Loss:0.1557 ||Epoch_G_Loss:0.0421
# timer:  1.4959 sec.
# -------------
# Epoch 133/300
# -------------
# （train）
# -------------
# epoch 133 || Epoch_D_Loss:0.1444 ||Epoch_G_Loss:0.0504
# timer:  1.5263 sec.
# -------------
# Epoch 134/300
# -------------
# （train）
# -------------
# epoch 134 || Epoch_D_Loss:0.1319 ||Epoch_G_Loss:0.0632
# timer:  1.4883 sec.
# -------------
# Epoch 135/300
# -------------
# （train）
# -------------
# epoch 135 || Epoch_D_Loss:0.1494 ||Epoch_G_Loss:0.0701
# timer:  1.5045 sec.
# -------------
# Epoch 136/300
# -------------
# （train）
# -------------
# epoch 136 || Epoch_D_Loss:0.1515 ||Epoch_G_Loss:0.0605
# timer:  1.4983 sec.
# -------------
# Epoch 137/300
# -------------
# （train）
# -------------
# epoch 137 || Epoch_D_Loss:0.1525 ||Epoch_G_Loss:0.0361
# timer:  1.4968 sec.
# -------------
# Epoch 138/300
# -------------
# （train）
# -------------
# epoch 138 || Epoch_D_Loss:0.1509 ||Epoch_G_Loss:0.0457
# timer:  1.4965 sec.
# -------------
# Epoch 139/300
# -------------
# （train）
# -------------
# epoch 139 || Epoch_D_Loss:0.1305 ||Epoch_G_Loss:0.0626
# timer:  1.5155 sec.
# -------------
# Epoch 140/300
# -------------
# （train）
# -------------
# epoch 140 || Epoch_D_Loss:0.1400 ||Epoch_G_Loss:0.0516
# timer:  1.4886 sec.
# -------------
# Epoch 141/300
# -------------
# （train）
# -------------
# epoch 141 || Epoch_D_Loss:0.1454 ||Epoch_G_Loss:0.0674
# timer:  1.4996 sec.
# -------------
# Epoch 142/300
# -------------
# （train）
# -------------
# epoch 142 || Epoch_D_Loss:0.1381 ||Epoch_G_Loss:0.0577
# timer:  1.4822 sec.
# -------------
# Epoch 143/300
# -------------
# （train）
# -------------
# epoch 143 || Epoch_D_Loss:0.1471 ||Epoch_G_Loss:0.0585
# timer:  1.5119 sec.
# -------------
# Epoch 144/300
# -------------
# （train）
# -------------
# epoch 144 || Epoch_D_Loss:0.1477 ||Epoch_G_Loss:0.0681
# timer:  1.4916 sec.
# -------------
# Epoch 145/300
# -------------
# （train）
# -------------
# epoch 145 || Epoch_D_Loss:0.1352 ||Epoch_G_Loss:0.0674
# timer:  1.4990 sec.
# -------------
# Epoch 146/300
# -------------
# （train）
# -------------
# epoch 146 || Epoch_D_Loss:0.1332 ||Epoch_G_Loss:0.0797
# timer:  1.5097 sec.
# -------------
# Epoch 147/300
# -------------
# （train）
# -------------
# epoch 147 || Epoch_D_Loss:0.1411 ||Epoch_G_Loss:0.0468
# timer:  1.5113 sec.
# -------------
# Epoch 148/300
# -------------
# （train）
# -------------
# epoch 148 || Epoch_D_Loss:0.1331 ||Epoch_G_Loss:0.0700
# timer:  1.5208 sec.
# -------------
# Epoch 149/300
# -------------
# （train）
# -------------
# epoch 149 || Epoch_D_Loss:0.1320 ||Epoch_G_Loss:0.0539
# timer:  1.5264 sec.
# -------------
# Epoch 150/300
# -------------
# （train）
# -------------
# epoch 150 || Epoch_D_Loss:0.1408 ||Epoch_G_Loss:0.0705
# timer:  1.5286 sec.
# -------------
# Epoch 151/300
# -------------
# （train）
# -------------
# epoch 151 || Epoch_D_Loss:0.1269 ||Epoch_G_Loss:0.0824
# timer:  1.5091 sec.
# -------------
# Epoch 152/300
# -------------
# （train）
# -------------
# epoch 152 || Epoch_D_Loss:0.1399 ||Epoch_G_Loss:0.0584
# timer:  1.5089 sec.
# -------------
# Epoch 153/300
# -------------
# （train）
# -------------
# epoch 153 || Epoch_D_Loss:0.1294 ||Epoch_G_Loss:0.0889
# timer:  1.5029 sec.
# -------------
# Epoch 154/300
# -------------
# （train）
# -------------
# epoch 154 || Epoch_D_Loss:0.1300 ||Epoch_G_Loss:0.0593
# timer:  1.5226 sec.
# -------------
# Epoch 155/300
# -------------
# （train）
# -------------
# epoch 155 || Epoch_D_Loss:0.1320 ||Epoch_G_Loss:0.0692
# timer:  1.5175 sec.
# -------------
# Epoch 156/300
# -------------
# （train）
# -------------
# epoch 156 || Epoch_D_Loss:0.1322 ||Epoch_G_Loss:0.0635
# timer:  1.4882 sec.
# -------------
# Epoch 157/300
# -------------
# （train）
# -------------
# epoch 157 || Epoch_D_Loss:0.1301 ||Epoch_G_Loss:0.0737
# timer:  1.5093 sec.
# -------------
# Epoch 158/300
# -------------
# （train）
# -------------
# epoch 158 || Epoch_D_Loss:0.1336 ||Epoch_G_Loss:0.0823
# timer:  1.4922 sec.
# -------------
# Epoch 159/300
# -------------
# （train）
# -------------
# epoch 159 || Epoch_D_Loss:0.1297 ||Epoch_G_Loss:0.0569
# timer:  1.5008 sec.
# -------------
# Epoch 160/300
# -------------
# （train）
# -------------
# epoch 160 || Epoch_D_Loss:0.1227 ||Epoch_G_Loss:0.0808
# timer:  1.5006 sec.
# -------------
# Epoch 161/300
# -------------
# （train）
# -------------
# epoch 161 || Epoch_D_Loss:0.1234 ||Epoch_G_Loss:0.0762
# timer:  1.4992 sec.
# -------------
# Epoch 162/300
# -------------
# （train）
# -------------
# epoch 162 || Epoch_D_Loss:0.1240 ||Epoch_G_Loss:0.0721
# timer:  1.5066 sec.
# -------------
# Epoch 163/300
# -------------
# （train）
# -------------
# epoch 163 || Epoch_D_Loss:0.1357 ||Epoch_G_Loss:0.0778
# timer:  1.4962 sec.
# -------------
# Epoch 164/300
# -------------
# （train）
# -------------
# epoch 164 || Epoch_D_Loss:0.1119 ||Epoch_G_Loss:0.0974
# timer:  1.5111 sec.
# -------------
# Epoch 165/300
# -------------
# （train）
# -------------
# epoch 165 || Epoch_D_Loss:0.1230 ||Epoch_G_Loss:0.0467
# timer:  1.5155 sec.
# -------------
# Epoch 166/300
# -------------
# （train）
# -------------
# epoch 166 || Epoch_D_Loss:0.1311 ||Epoch_G_Loss:0.0843
# timer:  1.5010 sec.
# -------------
# Epoch 167/300
# -------------
# （train）
# -------------
# epoch 167 || Epoch_D_Loss:0.1094 ||Epoch_G_Loss:0.0568
# timer:  1.5145 sec.
# -------------
# Epoch 168/300
# -------------
# （train）
# -------------
# epoch 168 || Epoch_D_Loss:0.1217 ||Epoch_G_Loss:0.0877
# timer:  1.4894 sec.
# -------------
# Epoch 169/300
# -------------
# （train）
# -------------
# epoch 169 || Epoch_D_Loss:0.1219 ||Epoch_G_Loss:0.0848
# timer:  1.5175 sec.
# -------------
# Epoch 170/300
# -------------
# （train）
# -------------
# epoch 170 || Epoch_D_Loss:0.1193 ||Epoch_G_Loss:0.0737
# timer:  1.4928 sec.
# -------------
# Epoch 171/300
# -------------
# （train）
# -------------
# epoch 171 || Epoch_D_Loss:0.1148 ||Epoch_G_Loss:0.0734
# timer:  1.4915 sec.
# -------------
# Epoch 172/300
# -------------
# （train）
# -------------
# epoch 172 || Epoch_D_Loss:0.1149 ||Epoch_G_Loss:0.0786
# timer:  1.4964 sec.
# -------------
# Epoch 173/300
# -------------
# （train）
# -------------
# epoch 173 || Epoch_D_Loss:0.1108 ||Epoch_G_Loss:0.0717
# timer:  1.5191 sec.
# -------------
# Epoch 174/300
# -------------
# （train）
# -------------
# epoch 174 || Epoch_D_Loss:0.1208 ||Epoch_G_Loss:0.1002
# timer:  1.5235 sec.
# -------------
# Epoch 175/300
# -------------
# （train）
# -------------
# epoch 175 || Epoch_D_Loss:0.1119 ||Epoch_G_Loss:0.0849
# timer:  1.4925 sec.
# -------------
# Epoch 176/300
# -------------
# （train）
# -------------
# epoch 176 || Epoch_D_Loss:0.1138 ||Epoch_G_Loss:0.0873
# timer:  1.5083 sec.
# -------------
# Epoch 177/300
# -------------
# （train）
# -------------
# epoch 177 || Epoch_D_Loss:0.1070 ||Epoch_G_Loss:0.0998
# timer:  1.5001 sec.
# -------------
# Epoch 178/300
# -------------
# （train）
# -------------
# epoch 178 || Epoch_D_Loss:0.0917 ||Epoch_G_Loss:0.1249
# timer:  1.4946 sec.
# -------------
# Epoch 179/300
# -------------
# （train）
# -------------
# epoch 179 || Epoch_D_Loss:0.1130 ||Epoch_G_Loss:0.0869
# timer:  1.5145 sec.
# -------------
# Epoch 180/300
# -------------
# （train）
# -------------
# epoch 180 || Epoch_D_Loss:0.1146 ||Epoch_G_Loss:0.0885
# timer:  1.4947 sec.
# -------------
# Epoch 181/300
# -------------
# （train）
# -------------
# epoch 181 || Epoch_D_Loss:0.1143 ||Epoch_G_Loss:0.0930
# timer:  1.5015 sec.
# -------------
# Epoch 182/300
# -------------
# （train）
# -------------
# epoch 182 || Epoch_D_Loss:0.1051 ||Epoch_G_Loss:0.1074
# timer:  1.4914 sec.
# -------------
# Epoch 183/300
# -------------
# （train）
# -------------
# epoch 183 || Epoch_D_Loss:0.1082 ||Epoch_G_Loss:0.1075
# timer:  1.5238 sec.
# -------------
# Epoch 184/300
# -------------
# （train）
# -------------
# epoch 184 || Epoch_D_Loss:0.1037 ||Epoch_G_Loss:0.0948
# timer:  1.5078 sec.
# -------------
# Epoch 185/300
# -------------
# （train）
# -------------
# epoch 185 || Epoch_D_Loss:0.1048 ||Epoch_G_Loss:0.0985
# timer:  1.4931 sec.
# -------------
# Epoch 186/300
# -------------
# （train）
# -------------
# epoch 186 || Epoch_D_Loss:0.0880 ||Epoch_G_Loss:0.1100
# timer:  1.4951 sec.
# -------------
# Epoch 187/300
# -------------
# （train）
# -------------
# epoch 187 || Epoch_D_Loss:0.1156 ||Epoch_G_Loss:0.1209
# timer:  1.5166 sec.
# -------------
# Epoch 188/300
# -------------
# （train）
# -------------
# epoch 188 || Epoch_D_Loss:0.0967 ||Epoch_G_Loss:0.0878
# timer:  1.4872 sec.
# -------------
# Epoch 189/300
# -------------
# （train）
# -------------
# epoch 189 || Epoch_D_Loss:0.0983 ||Epoch_G_Loss:0.1032
# timer:  1.5157 sec.
# -------------
# Epoch 190/300
# -------------
# （train）
# -------------
# epoch 190 || Epoch_D_Loss:0.1042 ||Epoch_G_Loss:0.1027
# timer:  1.4844 sec.
# -------------
# Epoch 191/300
# -------------
# （train）
# -------------
# epoch 191 || Epoch_D_Loss:0.0957 ||Epoch_G_Loss:0.1040
# timer:  1.5143 sec.
# -------------
# Epoch 192/300
# -------------
# （train）
# -------------
# epoch 192 || Epoch_D_Loss:0.0999 ||Epoch_G_Loss:0.1135
# timer:  1.5036 sec.
# -------------
# Epoch 193/300
# -------------
# （train）
# -------------
# epoch 193 || Epoch_D_Loss:0.0958 ||Epoch_G_Loss:0.1145
# timer:  1.4810 sec.
# -------------
# Epoch 194/300
# -------------
# （train）
# -------------
# epoch 194 || Epoch_D_Loss:0.0908 ||Epoch_G_Loss:0.1197
# timer:  1.4875 sec.
# -------------
# Epoch 195/300
# -------------
# （train）
# -------------
# epoch 195 || Epoch_D_Loss:0.0942 ||Epoch_G_Loss:0.1192
# timer:  1.5083 sec.
# -------------
# Epoch 196/300
# -------------
# （train）
# -------------
# epoch 196 || Epoch_D_Loss:0.0903 ||Epoch_G_Loss:0.1156
# timer:  1.4937 sec.
# -------------
# Epoch 197/300
# -------------
# （train）
# -------------
# epoch 197 || Epoch_D_Loss:0.0935 ||Epoch_G_Loss:0.1243
# timer:  1.5085 sec.
# -------------
# Epoch 198/300
# -------------
# （train）
# -------------
# epoch 198 || Epoch_D_Loss:0.0904 ||Epoch_G_Loss:0.1183
# timer:  1.5051 sec.
# -------------
# Epoch 199/300
# -------------
# （train）
# -------------
# epoch 199 || Epoch_D_Loss:0.0903 ||Epoch_G_Loss:0.1197
# timer:  1.5390 sec.
# -------------
# Epoch 200/300
# -------------
# （train）
# -------------
# epoch 200 || Epoch_D_Loss:0.0941 ||Epoch_G_Loss:0.1260
# timer:  1.4980 sec.
# -------------
# Epoch 201/300
# -------------
# （train）
# -------------
# epoch 201 || Epoch_D_Loss:0.0899 ||Epoch_G_Loss:0.1181
# timer:  1.4973 sec.
# -------------
# Epoch 202/300
# -------------
# （train）
# -------------
# epoch 202 || Epoch_D_Loss:0.0946 ||Epoch_G_Loss:0.1338
# timer:  1.4812 sec.
# -------------
# Epoch 203/300
# -------------
# （train）
# -------------
# epoch 203 || Epoch_D_Loss:0.0810 ||Epoch_G_Loss:0.1178
# timer:  1.5033 sec.
# -------------
# Epoch 204/300
# -------------
# （train）
# -------------
# epoch 204 || Epoch_D_Loss:0.0876 ||Epoch_G_Loss:0.1313
# timer:  1.4914 sec.
# -------------
# Epoch 205/300
# -------------
# （train）
# -------------
# epoch 205 || Epoch_D_Loss:0.0823 ||Epoch_G_Loss:0.1295
# timer:  1.5008 sec.
# -------------
# Epoch 206/300
# -------------
# （train）
# -------------
# epoch 206 || Epoch_D_Loss:0.0805 ||Epoch_G_Loss:0.1280
# timer:  1.5193 sec.
# -------------
# Epoch 207/300
# -------------
# （train）
# -------------
# epoch 207 || Epoch_D_Loss:0.0789 ||Epoch_G_Loss:0.1061
# timer:  1.5019 sec.
# -------------
# Epoch 208/300
# -------------
# （train）
# -------------
# epoch 208 || Epoch_D_Loss:0.0763 ||Epoch_G_Loss:0.1500
# timer:  1.4883 sec.
# -------------
# Epoch 209/300
# -------------
# （train）
# -------------
# epoch 209 || Epoch_D_Loss:0.0777 ||Epoch_G_Loss:0.1450
# timer:  1.4964 sec.
# -------------
# Epoch 210/300
# -------------
# （train）
# -------------
# epoch 210 || Epoch_D_Loss:0.0865 ||Epoch_G_Loss:0.1262
# timer:  1.4929 sec.
# -------------
# Epoch 211/300
# -------------
# （train）
# -------------
# epoch 211 || Epoch_D_Loss:0.0638 ||Epoch_G_Loss:0.1549
# timer:  1.4913 sec.
# -------------
# Epoch 212/300
# -------------
# （train）
# -------------
# epoch 212 || Epoch_D_Loss:0.0733 ||Epoch_G_Loss:0.1436
# timer:  1.4853 sec.
# -------------
# Epoch 213/300
# -------------
# （train）
# -------------
# epoch 213 || Epoch_D_Loss:0.0841 ||Epoch_G_Loss:0.1345
# timer:  1.5005 sec.
# -------------
# Epoch 214/300
# -------------
# （train）
# -------------
# epoch 214 || Epoch_D_Loss:0.0747 ||Epoch_G_Loss:0.1362
# timer:  1.4863 sec.
# -------------
# Epoch 215/300
# -------------
# （train）
# -------------
# epoch 215 || Epoch_D_Loss:0.0666 ||Epoch_G_Loss:0.1591
# timer:  1.4868 sec.
# -------------
# Epoch 216/300
# -------------
# （train）
# -------------
# epoch 216 || Epoch_D_Loss:0.0628 ||Epoch_G_Loss:0.1345
# timer:  1.4941 sec.
# -------------
# Epoch 217/300
# -------------
# （train）
# -------------
# epoch 217 || Epoch_D_Loss:0.0730 ||Epoch_G_Loss:0.1707
# timer:  1.5030 sec.
# -------------
# Epoch 218/300
# -------------
# （train）
# -------------
# epoch 218 || Epoch_D_Loss:0.0744 ||Epoch_G_Loss:0.1489
# timer:  1.4979 sec.
# -------------
# Epoch 219/300
# -------------
# （train）
# -------------
# epoch 219 || Epoch_D_Loss:0.0731 ||Epoch_G_Loss:0.1693
# timer:  1.4911 sec.
# -------------
# Epoch 220/300
# -------------
# （train）
# -------------
# epoch 220 || Epoch_D_Loss:0.0759 ||Epoch_G_Loss:0.1305
# timer:  1.4844 sec.
# -------------
# Epoch 221/300
# -------------
# （train）
# -------------
# epoch 221 || Epoch_D_Loss:0.0586 ||Epoch_G_Loss:0.1653
# timer:  1.4968 sec.
# -------------
# Epoch 222/300
# -------------
# （train）
# -------------
# epoch 222 || Epoch_D_Loss:0.0678 ||Epoch_G_Loss:0.1687
# timer:  1.5101 sec.
# -------------
# Epoch 223/300
# -------------
# （train）
# -------------
# epoch 223 || Epoch_D_Loss:0.0715 ||Epoch_G_Loss:0.1393
# timer:  1.5170 sec.
# -------------
# Epoch 224/300
# -------------
# （train）
# -------------
# epoch 224 || Epoch_D_Loss:0.0625 ||Epoch_G_Loss:0.1552
# timer:  1.5240 sec.
# -------------
# Epoch 225/300
# -------------
# （train）
# -------------
# epoch 225 || Epoch_D_Loss:0.0674 ||Epoch_G_Loss:0.1512
# timer:  1.5309 sec.
# -------------
# Epoch 226/300
# -------------
# （train）
# -------------
# epoch 226 || Epoch_D_Loss:0.0642 ||Epoch_G_Loss:0.1640
# timer:  1.5259 sec.
# -------------
# Epoch 227/300
# -------------
# （train）
# -------------
# epoch 227 || Epoch_D_Loss:0.0669 ||Epoch_G_Loss:0.1732
# timer:  1.5285 sec.
# -------------
# Epoch 228/300
# -------------
# （train）
# -------------
# epoch 228 || Epoch_D_Loss:0.0643 ||Epoch_G_Loss:0.1591
# timer:  1.5129 sec.
# -------------
# Epoch 229/300
# -------------
# （train）
# -------------
# epoch 229 || Epoch_D_Loss:0.0583 ||Epoch_G_Loss:0.1837
# timer:  1.5345 sec.
# -------------
# Epoch 230/300
# -------------
# （train）
# -------------
# epoch 230 || Epoch_D_Loss:0.0713 ||Epoch_G_Loss:0.1557
# timer:  1.4896 sec.
# -------------
# Epoch 231/300
# -------------
# （train）
# -------------
# epoch 231 || Epoch_D_Loss:0.0633 ||Epoch_G_Loss:0.1904
# timer:  1.4895 sec.
# -------------
# Epoch 232/300
# -------------
# （train）
# -------------
# epoch 232 || Epoch_D_Loss:0.0468 ||Epoch_G_Loss:0.1719
# timer:  1.4677 sec.
# -------------
# Epoch 233/300
# -------------
# （train）
# -------------
# epoch 233 || Epoch_D_Loss:0.0669 ||Epoch_G_Loss:0.1903
# timer:  1.5029 sec.
# -------------
# Epoch 234/300
# -------------
# （train）
# -------------
# epoch 234 || Epoch_D_Loss:0.0507 ||Epoch_G_Loss:0.1787
# timer:  1.5151 sec.
# -------------
# Epoch 235/300
# -------------
# （train）
# -------------
# epoch 235 || Epoch_D_Loss:0.0589 ||Epoch_G_Loss:0.1817
# timer:  1.4850 sec.
# -------------
# Epoch 236/300
# -------------
# （train）
# -------------
# epoch 236 || Epoch_D_Loss:0.0499 ||Epoch_G_Loss:0.1617
# timer:  1.4880 sec.
# -------------
# Epoch 237/300
# -------------
# （train）
# -------------
# epoch 237 || Epoch_D_Loss:0.0562 ||Epoch_G_Loss:0.1670
# timer:  1.4859 sec.
# -------------
# Epoch 238/300
# -------------
# （train）
# -------------
# epoch 238 || Epoch_D_Loss:0.0673 ||Epoch_G_Loss:0.1725
# timer:  1.4692 sec.
# -------------
# Epoch 239/300
# -------------
# （train）
# -------------
# epoch 239 || Epoch_D_Loss:0.0409 ||Epoch_G_Loss:0.1822
# timer:  1.5032 sec.
# -------------
# Epoch 240/300
# -------------
# （train）
# -------------
# epoch 240 || Epoch_D_Loss:0.0575 ||Epoch_G_Loss:0.1616
# timer:  1.5084 sec.
# -------------
# Epoch 241/300
# -------------
# （train）
# -------------
# epoch 241 || Epoch_D_Loss:0.0571 ||Epoch_G_Loss:0.2067
# timer:  1.4908 sec.
# -------------
# Epoch 242/300
# -------------
# （train）
# -------------
# epoch 242 || Epoch_D_Loss:0.0540 ||Epoch_G_Loss:0.1638
# timer:  1.5054 sec.
# -------------
# Epoch 243/300
# -------------
# （train）
# -------------
# epoch 243 || Epoch_D_Loss:0.0505 ||Epoch_G_Loss:0.1897
# timer:  1.5210 sec.
# -------------
# Epoch 244/300
# -------------
# （train）
# -------------
# epoch 244 || Epoch_D_Loss:0.0631 ||Epoch_G_Loss:0.1758
# timer:  1.4808 sec.
# -------------
# Epoch 245/300
# -------------
# （train）
# -------------
# epoch 245 || Epoch_D_Loss:0.0511 ||Epoch_G_Loss:0.2037
# timer:  1.4947 sec.
# -------------
# Epoch 246/300
# -------------
# （train）
# -------------
# epoch 246 || Epoch_D_Loss:0.0344 ||Epoch_G_Loss:0.1756
# timer:  1.4712 sec.
# -------------
# Epoch 247/300
# -------------
# （train）
# -------------
# epoch 247 || Epoch_D_Loss:0.0669 ||Epoch_G_Loss:0.2065
# timer:  1.5044 sec.
# -------------
# Epoch 248/300
# -------------
# （train）
# -------------
# epoch 248 || Epoch_D_Loss:0.0486 ||Epoch_G_Loss:0.1539
# timer:  1.4869 sec.
# -------------
# Epoch 249/300
# -------------
# （train）
# -------------
# epoch 249 || Epoch_D_Loss:0.0373 ||Epoch_G_Loss:0.1969
# timer:  1.4669 sec.
# -------------
# Epoch 250/300
# -------------
# （train）
# -------------
# epoch 250 || Epoch_D_Loss:0.0595 ||Epoch_G_Loss:0.2147
# timer:  1.4750 sec.
# -------------
# Epoch 251/300
# -------------
# （train）
# -------------
# epoch 251 || Epoch_D_Loss:0.0354 ||Epoch_G_Loss:0.1991
# timer:  1.4722 sec.
# -------------
# Epoch 252/300
# -------------
# （train）
# -------------
# epoch 252 || Epoch_D_Loss:0.0494 ||Epoch_G_Loss:0.2137
# timer:  1.4709 sec.
# -------------
# Epoch 253/300
# -------------
# （train）
# -------------
# epoch 253 || Epoch_D_Loss:0.0403 ||Epoch_G_Loss:0.1867
# timer:  1.4893 sec.
# -------------
# Epoch 254/300
# -------------
# （train）
# -------------
# epoch 254 || Epoch_D_Loss:0.0434 ||Epoch_G_Loss:0.2193
# timer:  1.4826 sec.
# -------------
# Epoch 255/300
# -------------
# （train）
# -------------
# epoch 255 || Epoch_D_Loss:0.0349 ||Epoch_G_Loss:0.1921
# timer:  1.4730 sec.
# -------------
# Epoch 256/300
# -------------
# （train）
# -------------
# epoch 256 || Epoch_D_Loss:0.0640 ||Epoch_G_Loss:0.1896
# timer:  1.4920 sec.
# -------------
# Epoch 257/300
# -------------
# （train）
# -------------
# epoch 257 || Epoch_D_Loss:0.0485 ||Epoch_G_Loss:0.1876
# timer:  1.4718 sec.
# -------------
# Epoch 258/300
# -------------
# （train）
# -------------
# epoch 258 || Epoch_D_Loss:0.0385 ||Epoch_G_Loss:0.2025
# timer:  1.5139 sec.
# -------------
# Epoch 259/300
# -------------
# （train）
# -------------
# epoch 259 || Epoch_D_Loss:0.0441 ||Epoch_G_Loss:0.1807
# timer:  1.4723 sec.
# -------------
# Epoch 260/300
# -------------
# （train）
# -------------
# epoch 260 || Epoch_D_Loss:0.0510 ||Epoch_G_Loss:0.2126
# timer:  1.4841 sec.
# -------------
# Epoch 261/300
# -------------
# （train）
# -------------
# epoch 261 || Epoch_D_Loss:0.0241 ||Epoch_G_Loss:0.2183
# timer:  1.4781 sec.
# -------------
# Epoch 262/300
# -------------
# （train）
# -------------
# epoch 262 || Epoch_D_Loss:0.0557 ||Epoch_G_Loss:0.2290
# timer:  1.4740 sec.
# -------------
# Epoch 263/300
# -------------
# （train）
# -------------
# epoch 263 || Epoch_D_Loss:0.0481 ||Epoch_G_Loss:0.2148
# timer:  1.4861 sec.
# -------------
# Epoch 264/300
# -------------
# （train）
# -------------
# epoch 264 || Epoch_D_Loss:0.0431 ||Epoch_G_Loss:0.2146
# timer:  1.4734 sec.
# -------------
# Epoch 265/300
# -------------
# （train）
# -------------
# epoch 265 || Epoch_D_Loss:0.0454 ||Epoch_G_Loss:0.2000
# timer:  1.4982 sec.
# -------------
# Epoch 266/300
# -------------
# （train）
# -------------
# epoch 266 || Epoch_D_Loss:0.0336 ||Epoch_G_Loss:0.2040
# timer:  1.4851 sec.
# -------------
# Epoch 267/300
# -------------
# （train）
# -------------
# epoch 267 || Epoch_D_Loss:0.0504 ||Epoch_G_Loss:0.2182
# timer:  1.4809 sec.
# -------------
# Epoch 268/300
# -------------
# （train）
# -------------
# epoch 268 || Epoch_D_Loss:0.0308 ||Epoch_G_Loss:0.2128
# timer:  1.4683 sec.
# -------------
# Epoch 269/300
# -------------
# （train）
# -------------
# epoch 269 || Epoch_D_Loss:0.0419 ||Epoch_G_Loss:0.2565
# timer:  1.4979 sec.
# -------------
# Epoch 270/300
# -------------
# （train）
# -------------
# epoch 270 || Epoch_D_Loss:0.0385 ||Epoch_G_Loss:0.2153
# timer:  1.4707 sec.
# -------------
# Epoch 271/300
# -------------
# （train）
# -------------
# epoch 271 || Epoch_D_Loss:0.0285 ||Epoch_G_Loss:0.2309
# timer:  1.4678 sec.
# -------------
# Epoch 272/300
# -------------
# （train）
# -------------
# epoch 272 || Epoch_D_Loss:0.0702 ||Epoch_G_Loss:0.2206
# timer:  1.4806 sec.
# -------------
# Epoch 273/300
# -------------
# （train）
# -------------
# epoch 273 || Epoch_D_Loss:0.0231 ||Epoch_G_Loss:0.1863
# timer:  1.4764 sec.
# -------------
# Epoch 274/300
# -------------
# （train）
# -------------
# epoch 274 || Epoch_D_Loss:0.0263 ||Epoch_G_Loss:0.2095
# timer:  1.5097 sec.
# -------------
# Epoch 275/300
# -------------
# （train）
# -------------
# epoch 275 || Epoch_D_Loss:0.0546 ||Epoch_G_Loss:0.2294
# timer:  1.4951 sec.
# -------------
# Epoch 276/300
# -------------
# （train）
# -------------
# epoch 276 || Epoch_D_Loss:0.0423 ||Epoch_G_Loss:0.2272
# timer:  1.4894 sec.
# -------------
# Epoch 277/300
# -------------
# （train）
# -------------
# epoch 277 || Epoch_D_Loss:0.0365 ||Epoch_G_Loss:0.2450
# timer:  1.4756 sec.
# -------------
# Epoch 278/300
# -------------
# （train）
# -------------
# epoch 278 || Epoch_D_Loss:0.0394 ||Epoch_G_Loss:0.2246
# timer:  1.5022 sec.
# -------------
# Epoch 279/300
# -------------
# （train）
# -------------
# epoch 279 || Epoch_D_Loss:0.0432 ||Epoch_G_Loss:0.2274
# timer:  1.4971 sec.
# -------------
# Epoch 280/300
# -------------
# （train）
# -------------
# epoch 280 || Epoch_D_Loss:0.0393 ||Epoch_G_Loss:0.1912
# timer:  1.4773 sec.
# -------------
# Epoch 281/300
# -------------
# （train）
# -------------
# epoch 281 || Epoch_D_Loss:0.0183 ||Epoch_G_Loss:0.2339
# timer:  1.4773 sec.
# -------------
# Epoch 282/300
# -------------
# （train）
# -------------
# epoch 282 || Epoch_D_Loss:0.0425 ||Epoch_G_Loss:0.2461
# timer:  1.4809 sec.
# -------------
# Epoch 283/300
# -------------
# （train）
# -------------
# epoch 283 || Epoch_D_Loss:0.0362 ||Epoch_G_Loss:0.2374
# timer:  1.4655 sec.
# -------------
# Epoch 284/300
# -------------
# （train）
# -------------
# epoch 284 || Epoch_D_Loss:0.0303 ||Epoch_G_Loss:0.2204
# timer:  1.4766 sec.
# -------------
# Epoch 285/300
# -------------
# （train）
# -------------
# epoch 285 || Epoch_D_Loss:0.0371 ||Epoch_G_Loss:0.2543
# timer:  1.5006 sec.
# -------------
# Epoch 286/300
# -------------
# （train）
# -------------
# epoch 286 || Epoch_D_Loss:0.0286 ||Epoch_G_Loss:0.2373
# timer:  1.4856 sec.
# -------------
# Epoch 287/300
# -------------
# （train）
# -------------
# epoch 287 || Epoch_D_Loss:0.0409 ||Epoch_G_Loss:0.2373
# timer:  1.5042 sec.
# -------------
# Epoch 288/300
# -------------
# （train）
# -------------
# epoch 288 || Epoch_D_Loss:0.0243 ||Epoch_G_Loss:0.2330
# timer:  1.4734 sec.
# -------------
# Epoch 289/300
# -------------
# （train）
# -------------
# epoch 289 || Epoch_D_Loss:0.0329 ||Epoch_G_Loss:0.2245
# timer:  1.4738 sec.
# -------------
# Epoch 290/300
# -------------
# （train）
# -------------
# epoch 290 || Epoch_D_Loss:0.0196 ||Epoch_G_Loss:0.2687
# timer:  1.4579 sec.
# -------------
# Epoch 291/300
# -------------
# （train）
# -------------
# epoch 291 || Epoch_D_Loss:0.0518 ||Epoch_G_Loss:0.2219
# timer:  1.4705 sec.
# -------------
# Epoch 292/300
# -------------
# （train）
# -------------
# epoch 292 || Epoch_D_Loss:0.0357 ||Epoch_G_Loss:0.2522
# timer:  1.4689 sec.
# -------------
# Epoch 293/300
# -------------
# （train）
# -------------
# epoch 293 || Epoch_D_Loss:0.0226 ||Epoch_G_Loss:0.2304
# timer:  1.4741 sec.
# -------------
# Epoch 294/300
# -------------
# （train）
# -------------
# epoch 294 || Epoch_D_Loss:0.0346 ||Epoch_G_Loss:0.2281
# timer:  1.4807 sec.
# -------------
# Epoch 295/300
# -------------
# （train）
# -------------
# epoch 295 || Epoch_D_Loss:0.0300 ||Epoch_G_Loss:0.2461
# timer:  1.4710 sec.
# -------------
# Epoch 296/300
# -------------
# （train）
# -------------
# epoch 296 || Epoch_D_Loss:0.0479 ||Epoch_G_Loss:0.2394
# timer:  1.4816 sec.
# -------------
# Epoch 297/300
# -------------
# （train）
# -------------
# epoch 297 || Epoch_D_Loss:0.0243 ||Epoch_G_Loss:0.2603
# timer:  1.4876 sec.
# -------------
# Epoch 298/300
# -------------
# （train）
# -------------
# epoch 298 || Epoch_D_Loss:0.0290 ||Epoch_G_Loss:0.2387
# timer:  1.5050 sec.
# -------------
# Epoch 299/300
# -------------
# （train）
# -------------
# epoch 299 || Epoch_D_Loss:0.0188 ||Epoch_G_Loss:0.2452
# timer:  1.4805 sec.

# %%
# 生成画像と訓練データを可視化する
# 本セルは、良い感じの画像が生成されるまで、何度か実行をし直しています

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 入力の乱数生成
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)

# 画像生成
G_update.eval()
fake_images, am1, am2 = G_update(fixed_z.to(device))

# 訓練データ
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す


# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %%
# Attentiom Mapを出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):

    # 上段に生成した画像データを
    plt.subplot(2, 5, i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

    # 下段にAttentin Map1の画像中央のピクセルのデータを
    plt.subplot(2, 5, 5+i+1)
    am = am1[i].view(16, 16, 16, 16)
    am = am[7][7]  # 中央に着目
    plt.imshow(am.cpu().detach().numpy(), 'Reds')

# %% [markdown]
# 以上
