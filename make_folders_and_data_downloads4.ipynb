# %% [markdown]
# ##  第4章 姿勢推定の準備ファイル
#
# - 本ファイルでは、第4章で使用するフォルダの作成とファイルのダウンロードを行います。

# %%
import os
import urllib.request
import zipfile
import tarfile

# %%
pwd
# Out:
# '/content'

# %%
ls
# Out:
# sample_data/

# %%
#cd "/content/drive/My Drive/Colab Notebooks/pytorch_advanced/4_pose_estimation"
# Out:
# /content/drive/My Drive/Colab Notebooks/pytorch_advanced/4_pose_estimation

# %% [markdown]
# # まずはgoogleドライブに保存するのではなく、セッションストレージに保存

# %%
cd "sample_data"
# Out:
# /content/sample_data

# %%
# フォルダ「data」が存在しない場合は作成する
data_dir = "./../data/"
if not os.path.exists(data_dir):
    os.mkdir(data_dir)

# %%
# フォルダ「weights」が存在しない場合は作成する
weights_dir = "./weights/"
if not os.path.exists(weights_dir):
    os.mkdir(weights_dir)

# %%
# MSCOCOの2014 Val images [41K/6GB]をダウンロード
# 6GBのダウンロードと解凍なので時間がかかります（10分弱）
url =  "http://images.cocodataset.org/zips/val2014.zip"
target_path = os.path.join(data_dir, "val2014.zip") 

if not os.path.exists(target_path):
    urllib.request.urlretrieve(url, target_path)
    
    zip = zipfile.ZipFile(target_path)
    zip.extractall(data_dir)  # ZIPを解凍
    zip.close()  # ZIPファイルをクローズ

# %% [markdown]
# # セッションストレージに保存後、解凍されたものだけをgoogleドライブに保存

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd "/content/drive/My Drive/Colab Notebooks/pytorch_advanced/4_pose_estimation"
# Out:
# /content/drive/My Drive/Colab Notebooks/pytorch_advanced/4_pose_estimation

# %%
# !mv "/content/data/val2014" "/content/drive/My Drive/Colab Notebooks/pytorch_advanced/data"

# %% [markdown]
# ## tensorboyさんのGitHubから必要なデータを手動ダウンロード
#
# tensorboyさんがCOCODatasetから使用しやすいように、加工したデータを使用します
#
# https://github.com/tensorboy/pytorch_Realtime_Multi-Person_Pose_Estimation
#
# Released under the MIT license

# %%
# 画像データのアノテーションデータを整理したファイル「COCO.json」をダウンロードします。

フォルダ「data」に以下のデータを配置
アノテーションデータ「COCO.json」

https://www.dropbox.com/s/0sj2q24hipiiq5t/COCO.json?dl=0
# Out:
#   File "<ipython-input-12-44f9e059f8ae>", line 3
#     フォルダ「data」に以下のデータを配置
#                        ^
# SyntaxError: invalid character in identifier

# %%
# 画像中でアノテーション（人の関節位置の情報）がない人の部分をマスクするデータを用意します。

フォルダ「data」に以下のデータ「mask.tar.gz」を配置
マスクデータ「mask.tar.gz」

https://www.dropbox.com/s/bd9ty7b4fqd5ebf/mask.tar.gz?dl=0

# %%
# !wget https://www.dropbox.com/s/bd9ty7b4fqd5ebf/mask.tar.gz
# Out:
# --2021-02-25 16:26:48--  https://www.dropbox.com/s/bd9ty7b4fqd5ebf/mask.tar.gz
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/bd9ty7b4fqd5ebf/mask.tar.gz [following]
# --2021-02-25 16:26:49--  https://www.dropbox.com/s/raw/bd9ty7b4fqd5ebf/mask.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc59a3eacbd829563765575af61.dl.dropboxusercontent.com/cd/0/inline/BJnWKECSZapWvJJolF7j7nmvmbvvA_um4IsX5m3pHHZCqu7preTyIuJP6k6FxHPeNX-dbxrkVaQI2tQKwmYW7ANeZq-b7kUrhyZyt1WZ3cEitw/file# [following]
# --2021-02-25 16:26:49--  https://ucc59a3eacbd829563765575af61.dl.dropboxusercontent.com/cd/0/inline/BJnWKECSZapWvJJolF7j7nmvmbvvA_um4IsX5m3pHHZCqu7preTyIuJP6k6FxHPeNX-dbxrkVaQI2tQKwmYW7ANeZq-b7kUrhyZyt1WZ3cEitw/file
# Resolving ucc59a3eacbd829563765575af61.dl.dropboxusercontent.com (ucc59a3eacbd829563765575af61.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to ucc59a3eacbd829563765575af61.dl.dropboxusercontent.com (ucc59a3eacbd829563765575af61.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BJklXd5ynJUShhCNx_BQcCSWQ39v7pLr7NFJ5oRwPL-Y32wq0LK9xaTNbw0xe7tTXDfPloFyK2FuYruNukAQ78qDrGn8c2EAD7KA8ljG81rD-t1Fy28TG_ssgFo0K5H98fwSGmd4_7ss4MiH98jtZKfqETVjpeFh2yjnjEBtEfgBBSJHX2NI5O3yPHJfUDicJeKEbToBOAU_e4IwZttNCKKESjoZwSz5Zh43UNJSzsU87BYykGwAob8vKdfToL4-neptqafy_SnvEztNjyeFZX65FoA43agiTYa5OTzBirTkbmwJj7o8WosiLsWOYaOUgJiaB_MF_C1eu5w5cYr3qWmM/file [following]
# --2021-02-25 16:26:50--  https://ucc59a3eacbd829563765575af61.dl.dropboxusercontent.com/cd/0/inline2/BJklXd5ynJUShhCNx_BQcCSWQ39v7pLr7NFJ5oRwPL-Y32wq0LK9xaTNbw0xe7tTXDfPloFyK2FuYruNukAQ78qDrGn8c2EAD7KA8ljG81rD-t1Fy28TG_ssgFo0K5H98fwSGmd4_7ss4MiH98jtZKfqETVjpeFh2yjnjEBtEfgBBSJHX2NI5O3yPHJfUDicJeKEbToBOAU_e4IwZttNCKKESjoZwSz5Zh43UNJSzsU87BYykGwAob8vKdfToL4-neptqafy_SnvEztNjyeFZX65FoA43agiTYa5OTzBirTkbmwJj7o8WosiLsWOYaOUgJiaB_MF_C1eu5w5cYr3qWmM/file
# Reusing existing connection to ucc59a3eacbd829563765575af61.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 30591896 (29M) [application/octet-stream]
# Saving to: ‘mask.tar.gz’
#
# mask.tar.gz         100%[===================>]  29.17M  52.5MB/s    in 0.6s
#
# 2021-02-25 16:26:51 (52.5 MB/s) - ‘mask.tar.gz’ saved [30591896/30591896]

# %% [markdown]
# ## mask.tar.gzを以下で解凍します

# %%
data_dir
# Out:
# './../data/'

# %%
pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks/pytorch_advanced/4_pose_estimation'

# %%
save_path = os.path.join(data_dir, "mask.tar.gz")

# %%
# mask.tar.gzの解凍
with tarfile.open(save_path, 'r:*') as tar:
    tar.extractall(data_dir)

# %% [markdown]
# # 学習済みモデルのダウンロード

# %%
# tensorboyさんによる、学習済みのOpenPoseモデル「pspnet50_30.pth」を用意します。

フォルダ「weights」に以下の「pose_model_scratch.pth」を配置
学習済みモデル「pose_model_scratch.pth」

https://www.dropbox.com/s/5v654d2u65fuvyr/pose_model_scratch.pth?dl=0

# %%
# !wget https://www.dropbox.com/s/5v654d2u65fuvyr/pose_model_scratch.pth
# Out:
# --2021-02-25 16:26:29--  https://www.dropbox.com/s/5v654d2u65fuvyr/pose_model_scratch.pth
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/5v654d2u65fuvyr/pose_model_scratch.pth [following]
# --2021-02-25 16:26:30--  https://www.dropbox.com/s/raw/5v654d2u65fuvyr/pose_model_scratch.pth
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc56c9c74f0ecc1cdbb9a8d1945e.dl.dropboxusercontent.com/cd/0/inline/BJnos0qqtAwDbKZdShUl2ZT_-owZhADgBuNAyHgSNAcmIvdh0M8CS8vKOSrZrhVLpUnfqH7lb6rdu4INi-K95pWJtTHivcVBaOexwrdAH4zQqw/file# [following]
# --2021-02-25 16:26:30--  https://uc56c9c74f0ecc1cdbb9a8d1945e.dl.dropboxusercontent.com/cd/0/inline/BJnos0qqtAwDbKZdShUl2ZT_-owZhADgBuNAyHgSNAcmIvdh0M8CS8vKOSrZrhVLpUnfqH7lb6rdu4INi-K95pWJtTHivcVBaOexwrdAH4zQqw/file
# Resolving uc56c9c74f0ecc1cdbb9a8d1945e.dl.dropboxusercontent.com (uc56c9c74f0ecc1cdbb9a8d1945e.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uc56c9c74f0ecc1cdbb9a8d1945e.dl.dropboxusercontent.com (uc56c9c74f0ecc1cdbb9a8d1945e.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BJnPnV2ilW6cLA-zBUtNaGXEomJXS8wt0BGxeP8j8tPZ8--VjTRjhqEOCxwK-7dx7PPc0U29uhP3K6DWKV6QhU81L2hDd8UFiDUN3B8qjwrhbIhIgyyDxT4GepnsPc04wHxXgpMCyvTovCLXt2nWiWe6QbDvBkxeLvkaHFYgEpM2a6OqTNHOAUsv88MU3agPD4Fre7tLBxiQdbv-odjBmedpJ3L9iU4pGeN9YB5a9kfbzCtjY3AnONJQz7AxD7Tc-kqQdX9LKQdPhWC4PlTlVJwbj_3pnY3NPPMyswZ8jwhRq2D3WHvjb00GTJjf1MANPv_6AIx4Wqn55C6AT1nvPqqt/file [following]
# --2021-02-25 16:26:31--  https://uc56c9c74f0ecc1cdbb9a8d1945e.dl.dropboxusercontent.com/cd/0/inline2/BJnPnV2ilW6cLA-zBUtNaGXEomJXS8wt0BGxeP8j8tPZ8--VjTRjhqEOCxwK-7dx7PPc0U29uhP3K6DWKV6QhU81L2hDd8UFiDUN3B8qjwrhbIhIgyyDxT4GepnsPc04wHxXgpMCyvTovCLXt2nWiWe6QbDvBkxeLvkaHFYgEpM2a6OqTNHOAUsv88MU3agPD4Fre7tLBxiQdbv-odjBmedpJ3L9iU4pGeN9YB5a9kfbzCtjY3AnONJQz7AxD7Tc-kqQdX9LKQdPhWC4PlTlVJwbj_3pnY3NPPMyswZ8jwhRq2D3WHvjb00GTJjf1MANPv_6AIx4Wqn55C6AT1nvPqqt/file
# Reusing existing connection to uc56c9c74f0ecc1cdbb9a8d1945e.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 209282651 (200M) [application/octet-stream]
# Saving to: ‘pose_model_scratch.pth.1’
#
# pose_model_scratch. 100%[===================>] 199.59M  60.2MB/s    in 3.3s
#
# 2021-02-25 16:26:35 (60.2 MB/s) - ‘pose_model_scratch.pth.1’ saved [209282651/209282651]

# %%
【※（実施済み）】
草野球の画像を手動でダウンロード

https://pixabay.com/ja/photos/%E3%83%92%E3%83%83%E3%83%88-%E3%82%AD%E3%83%A3%E3%83%83%E3%83%81%E3%83%A3%E3%83%BC-%E9%87%8E%E7%90%83-1407826/

の640×426サイズの画像
（画像権利情報：商用利用無料、帰属表示は必要ありません）

を、フォルダ「data」の直下に置く。

# %%
# !wget https://cdn.pixabay.com/photo/2016/05/22/01/38/hit-1407826_960_720.jpg
# Out:
# --2021-02-25 16:20:55--  https://cdn.pixabay.com/photo/2016/05/22/01/38/hit-1407826_960_720.jpg
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 104.18.21.183, 104.18.20.183, 2606:4700::6812:15b7, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|104.18.21.183|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 140166 (137K) [image/jpeg]
# Saving to: ‘hit-1407826_960_720.jpg’
#
# hit-1407826_960_720 100%[===================>] 136.88K  --.-KB/s    in 0.03s
#
# 2021-02-25 16:20:55 (5.00 MB/s) - ‘hit-1407826_960_720.jpg’ saved [140166/140166]

# %% [markdown]
# 以上
